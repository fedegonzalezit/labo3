# %%
from pipeline import Pipeline
from pipeline.steps import *

xgb_params = {
    "colsample_bylevel": 0.4778015829774066,
    "colsample_bynode": 0.362764358742407,
    "colsample_bytree": 0.7107423488010493,
    "gamma": 1.7094857725240398,
    "learning_rate": 0.02213323588455387,
    "max_depth": 20,
    "max_leaves": 512,
    "min_child_weight": 16,
    "n_estimators": 1667,
    "n_jobs": -1,
    "random_state": 42,
    "reg_alpha": 39.352415706891264,
    "reg_lambda": 75.44843704068275,
    "subsample": 0.06566669853471274,
    "verbose": 0,
}

class FeatureEngineeringProductCatInteractionStep(PipelineStep):

    def __init__(self, cat="cat1", name: Optional[str] = None, tn="tn"):
        super().__init__(name)
        self.cat = cat
        self.tn = tn


    def execute(self, df, df_original=None) -> None:
        # agrupo el dataframe por cat1 (sumando), obteniendo fecha, cat1 y
        # luego paso el dataframe a wide format, donde cada columna es una categoria  y la fila es la suma de tn para cada cat1
        # luego mergeo al dataframe original por fecha y product_id
        df_index = df.index
        if df_original is None:
            df_to_proces = df
        else:
            df_to_proces = df_original
        df_cat = df_to_proces.groupby(["date_id", self.cat]).agg({self.tn: "sum"}).reset_index()
        print(df_cat)
        df_cat = df_cat.pivot(index="date_id", columns=self.cat, values=self.tn).reset_index()
        # paso a string los nombres de las columnas
        df_cat.columns = [f"{self.tn}_{self.cat}_{col}" if col != "date_id" else "date_id" for col in df_cat.columns]
        df = df.merge(df_cat, on="date_id", how="left")
        # vuelvo a setear el indice original
        df.index = df_index
        return {"df": df}
    

import numpy as np
class Log1pTranformation(PipelineStep):
    def execute(self, df):
        df["tn"] = df["tn"].apply(lambda x: np.log1p(x) if x >= 0 else 0)
        return {"df": df}
    
class InverseLog1pTranformation(PipelineStep):
    def execute(self, df, predictions, y_test):
        df["target"] = df["target"].apply(lambda x: np.expm1(x) if x >= 0 else 0)
        predictions = predictions.apply(lambda x: np.expm1(x) if x >= 0 else 0)
        y_test["target"] = y_test["target"].apply(lambda x: np.expm1(x) if x >= 0 else 0)
        return {"df": df, "predictions": predictions, "y_test": y_test}

class GroupByProductStep(PipelineStep):
    def execute(self, df) -> None:
        # Agrupo el dataframe por product_id y fecha, sumando las cantidades
        df = df.groupby(["product_id", "fecha"]).agg({
            'cust_request_qty': 'sum',
            'cust_request_tn': 'sum',
            'tn': 'sum',
            'stock_final': 'max',
            'cat1': 'first',
            'cat2': 'first',
            'cat3': 'first',
            'brand': 'first',
            'sku_size': 'max',
        }).reset_index()
        # le dejo la columna customer_id = 0 para que no crashee el resto
        df['customer_id'] = 1
        return {"df": df}

class FilterDatasetByColumn(PipelineStep):
    def __init__(self, column: str, value, name: Optional[str] = None):
        super().__init__(name)
        self.column = column
        self.value = value
        
    def execute(self, df) -> None:
        # Filtra el DataFrame por el valor de la columna especificada
        df_original = df.copy()
        df_filtered = df[df[self.column] == self.value]
        print(df_filtered.shape)
        return {"df": df_filtered, "df_original": df_original}

class DeleteBadColumns(PipelineStep):
    def execute(self, df) -> None:
        # Elimina  las columnas donde toda sus filas son NaN
        base_columns = df.columns
        df = df.dropna(axis=1, how='all')
        df = df.loc[:, (df != 0).any(axis=0)]
        deleted_columns = set(base_columns) - set(df.columns)
        print(f"Deleted columns: {deleted_columns}")
        return {"df": df}

class CreateResidualTargetStep(PipelineStep):
    def __init__(self, name: Optional[str] = None, target_col: str = 'tn', window: int = 12):
        super().__init__(name)
        self.target_col = target_col
        self.window = window

    def execute(self, df: pd.DataFrame) -> Dict:
        df = df.sort_values(['product_id', 'customer_id', 'fecha']).copy()

        # Valor futuro (shift -2) que será la predicción final
        df['target_shifted'] = df.groupby(['product_id', 'customer_id'])[self.target_col].shift(-2)

        # Cálculo del valor base usando la media rolling pasada
        df['base_prediction'] = (
            df.groupby(['product_id', 'customer_id'])[self.target_col]
            .transform(lambda x: x.rolling(self.window, min_periods=1).mean())
        )

        # Target: residuo a predecir
        df['target'] = df['target_shifted'] - df['base_prediction']
        df.drop(columns=['target_shifted', 'base_prediction'], inplace=True, errors='ignore')

        return {
            "df": df,
            "target_col": self.target_col,
        }

class InverseResidualTargetStep(PipelineStep):
    def __init__(
        self,
        name: Optional[str] = None,
        target_col: str = 'tn',
        window: int = 12
    ):
        super().__init__(name)
        self.target_col = target_col
        self.window = window

    def execute(self, df: pd.DataFrame, predictions, y_test) -> Dict:

        # Orden correcto
        df = df.sort_values(['product_id', 'customer_id', 'fecha'])

        # Recalcular base_prediction exactamente como en CreateResidualTargetStep
        df['base_prediction'] = (
            df.groupby(['product_id', 'customer_id'])[self.target_col]
            .transform(lambda x: x.rolling(self.window, min_periods=1).mean())
        )

        # Invertir el target residual: target_original = residual + base_prediction
        df['target'] = df['target'] + df['base_prediction']

        predictions = predictions + df['base_prediction'].loc[y_test.index]

        y_test = df[["target"]].loc[y_test.index]
        # Limpiar si no querés guardar la base
        df.drop(columns=['base_prediction'], inplace=True)

        return {"df": df, "predictions": predictions, "y_test": y_test}

# %%
pipeline = Pipeline(
    steps=[
        LoadDataFrameStep("df_intermedio.parquet"),
    ]
)
pipeline.run()
# Out:
# Executing step: LoadDataFrameStep
# Step LoadDataFrameStep completed in 2.27 seconds

# %%
df = pipeline.get_artifact("df")
# get unique brands
brands = df["brand"].unique()
del df
import gc
gc.collect()
brands
# Out:
# ['ARIEL', 'LIMPIEX', 'NATURA', 'DOWNY', 'ROPEX1', ..., 'INDUSTRIAL', NaN, 'TWININGS', 'SKIN1', 'VICHY']
# Length: 38
# Categories (37, object): ['ARIEL', 'AYUDIN', 'CAPILATIS', 'COLBERT', ..., 'SKIN1', 'TWININGS', 'VICHY', 'VIVERE']

# %%
pipeline_results = {}
for brand in brands:
    print(f"Processing brand: {brand}")
    pipeline = Pipeline(
        steps=[
            LoadDataFrameStep("df_intermedio.parquet"),
            #GroupByProductStep(),
            DateRelatedFeaturesStep(),

            FilterDatasetByColumn(column="brand", value=brand),
            #Log1pTranformation(),
            #CreateTargetColumDiffStep(target_col="tn"),
            #CreateTargetColumStep(target_col="tn"),
            CreateResidualTargetStep(target_col="tn", window=12),
            ReduceMemoryUsageStep(),

            #ReduceMemoryUsageStep(),
            FeatureEngineeringLagStep(lags=[1,2,3,5,11,23], columns=["tn", "cust_request_qty", "stock_final"]),
            RollingMeanFeatureStep(window=3, columns=["tn", "cust_request_qty", "stock_final"]),
            RollingMaxFeatureStep(window=3, columns=["tn", "cust_request_qty", "stock_final"]),
            RollingMinFeatureStep(window=3, columns=["tn", "cust_request_qty", "stock_final"]),
            RollingMeanFeatureStep(window=9, columns=["tn", "cust_request_qty", "stock_final"]),
            RollingMaxFeatureStep(window=9, columns=["tn", "cust_request_qty", "stock_final"]),
            RollingMinFeatureStep(window=9, columns=["tn", "cust_request_qty", "stock_final"]),

            ReduceMemoryUsageStep(),

            RollingStdFeatureStep(window=3, columns=["tn", "cust_request_qty"]),
            RollingStdFeatureStep(window=6, columns=["tn", "cust_request_qty"]),
            RollingStdFeatureStep(window=12, columns=["tn", "cust_request_qty"]), 

            RollingSkewFeatureStep(window=3, columns=["tn", "cust_request_qty"]),
            RollingSkewFeatureStep(window=6, columns=["tn", "cust_request_qty"]),
            RollingSkewFeatureStep(window=12, columns=["tn", "cust_request_qty"]),
            ReduceMemoryUsageStep(),

            RollingZscoreFeatureStep(window=3, columns=["tn", "cust_request_qty"]),
            RollingZscoreFeatureStep(window=6, columns=["tn", "cust_request_qty"]),
            RollingZscoreFeatureStep(window=12, columns=["tn", "cust_request_qty"]),
            DiffFeatureStep(periods=1, columns=["tn", "cust_request_qty", "stock_final"]),
            DiffFeatureStep(periods=2, columns=["tn", "cust_request_qty", "stock_final"]),
            DiffFeatureStep(periods=3, columns=["tn", "cust_request_qty", "stock_final"]),
            DiffFeatureStep(periods=4, columns=["tn", "cust_request_qty", "stock_final"]),
            DiffFeatureStep(periods=5, columns=["tn", "cust_request_qty", "stock_final"]),
            DiffFeatureStep(periods=11, columns=["tn", "cust_request_qty", "stock_final"]),
            FeatureEngineeringProductCatInteractionStep(cat="cat1", tn="tn"),
            FeatureEngineeringProductCatInteractionStep(cat="cat2", tn="tn"),
            FeatureEngineeringProductCatInteractionStep(cat="cat3", tn="tn"),
            #FeatureEngineeringProductCatInteractionStep(cat="product_id", tn="tn"),

            CreateTotalCategoryStep(cat="cat1"),
            CreateTotalCategoryStep(cat="cat2"),
            CreateTotalCategoryStep(cat="cat3"),
            CreateTotalCategoryStep(cat="brand"),
            CreateTotalCategoryStep(cat="customer_id"),
            CreateTotalCategoryStep(cat="product_id"),
                    
            CreateTotalCategoryStep(cat="cat1", tn="stock_final"),
            CreateTotalCategoryStep(cat="cat2", tn="stock_final"),
            CreateTotalCategoryStep(cat="cat3", tn="stock_final"),

            #ReduceMemoryUsageStep(),
            FeatureDivInteractionStep(columns=[
                    ("tn", "tn_cat1_vendidas"), 
                    ("tn", "tn_cat2_vendidas"), 
                    ("tn", "tn_cat3_vendidas"), 
                    ("tn", "tn_brand_vendidas")]
            ),
            #ReduceMemoryUsageStep(),

            FeatureProdInteractionStep(columns=[("tn", "cust_request_qty")]),
            CreateWeightByCustomerStep(),
            CreateWeightByProductStep(),
            ReduceMemoryUsageStep(),
            DeleteBadColumns(),
            FilterProductsIDStep(dfs=["df"]),
            SplitDataFrameStep2(df="df", test_date=29, gap=1),
            PrepareXYStep(),
            TrainModelStep(params={"num_leaves":31, "feature_fraction":0.2}),
            PredictStep(),
            InverseResidualTargetStep(),
            #InverseLog1pTranformation(),
            InverseScalePredictionsStep(),
            IntegratePredictionsStep(),
            EvaluatePredictionsSteps(),
            EvaluatePredictionsOptimizatedSteps(), 
            #PlotFeatureImportanceStep(),

        ],
        optimize_arftifacts_memory=True
    )

    try: 
        pipeline.run()
        
        # Save the results
        pipeline_results[brand] = {
            "eval_df": pipeline.get_artifact("eval_df"),
            "alpha_opt": pipeline.get_artifact("alpha_opt"),
        }
    except Exception as e:
        print(f"Error processing brand {brand}: {e}")
        continue
# Out:
# Processing brand: ARIEL
# Executing step: LoadDataFrameStep
# Step LoadDataFrameStep completed in 2.33 seconds
# Executing step: DateRelatedFeaturesStep
# Step DateRelatedFeaturesStep completed in 5.09 seconds
# Executing step: FilterDatasetByColumn
# (377832, 17)
# Step FilterDatasetByColumn completed in 2.74 seconds
# Executing step: CreateResidualTargetStep
# Step CreateResidualTargetStep completed in 3.45 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 30.63 MB
# --- Memory usage after: 15.13 MB
# --- Decreased memory usage by 50.6%
#
# Step ReduceMemoryUsageStep completed in 0.06 seconds
# Executing step: FeatureEngineeringLagStep
# Step FeatureEngineeringLagStep completed in 0.16 seconds
# Executing step: RollingMeanFeatureStep
# Step RollingMeanFeatureStep completed in 9.91 seconds
# Executing step: RollingMaxFeatureStep
# Step RollingMaxFeatureStep completed in 9.55 seconds
# Executing step: RollingMinFeatureStep
# Step RollingMinFeatureStep completed in 9.74 seconds
# Executing step: RollingMeanFeatureStep
# Step RollingMeanFeatureStep completed in 10.20 seconds
# Executing step: RollingMaxFeatureStep
# Step RollingMaxFeatureStep completed in 9.70 seconds
# Executing step: RollingMinFeatureStep
# Step RollingMinFeatureStep completed in 9.73 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 92.97 MB
# --- Memory usage after: 41.08 MB
# --- Decreased memory usage by 55.8%
#
# Step ReduceMemoryUsageStep completed in 0.34 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 7.42 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 7.63 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 7.62 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 7.54 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 7.56 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 7.48 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 75.67 MB
# --- Memory usage after: 49.73 MB
# --- Decreased memory usage by 34.3%
#
# Step ReduceMemoryUsageStep completed in 0.46 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 14.26 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 13.84 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 14.14 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.17 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.19 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.18 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.19 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.20 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.21 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#      date_id   cat1            tn
# 0          0  FOODS   6490.774902
# 1          0     HC  20304.287109
# 2          0     PC   7183.233887
# 3          0    REF      8.984159
# 4          1  FOODS   7096.089844
# ..       ...    ...           ...
# 139       34    REF      0.470640
# 140       35  FOODS   4907.414551
# 141       35     HC  16045.644531
# 142       35     PC   5263.639160
# 143       35    REF      0.368930
#
# [144 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 1.22 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#      date_id            cat2           tn
# 0          0        ADEREZOS  4844.348145
# 1          0         CABELLO  4586.802246
# 2          0          DENTAL     1.525830
# 3          0            DEOS  1178.932739
# 4          0           HOGAR  2795.374268
# ..       ...             ...          ...
# 535       35     ROPA LAVADO  9541.868164
# 536       35    ROPA MANCHAS   207.274765
# 537       35  SOPAS Y CALDOS   722.231995
# 538       35              TE     0.368930
# 539       35         VAJILLA  2469.144287
#
# [540 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 1.30 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#       date_id              cat3           tn
# 0           0    ACONDICIONADOR  3565.031982
# 1           0        Acond Bebe     0.000000
# 2           0       Acond Mujer   245.138306
# 3           0              Aero   795.659119
# 4           0       Aji Picante     6.321310
# ...       ...               ...          ...
# 3343       35    Toallitas Bebe     5.400110
# 3344       35   Tratamiento Fem     3.135710
# 3345       35  Tratamiento Masc     4.049170
# 3346       35             Verde     0.034220
# 3347       35           Vidrios   230.734436
#
# [3348 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 1.59 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.79 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.65 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.69 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.73 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.73 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.69 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.70 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.70 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.77 seconds
# Executing step: FeatureDivInteractionStep
# Step FeatureDivInteractionStep completed in 0.55 seconds
# Executing step: FeatureProdInteractionStep
# Step FeatureProdInteractionStep completed in 0.53 seconds
# Executing step: CreateWeightByCustomerStep
# Step CreateWeightByCustomerStep completed in 0.77 seconds
# Executing step: CreateWeightByProductStep
# Step CreateWeightByProductStep completed in 0.79 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 272.41 MB
# --- Memory usage after: 163.59 MB
# --- Decreased memory usage by 39.9%
#
# Step ReduceMemoryUsageStep completed in 1.28 seconds
# Executing step: DeleteBadColumns
# Deleted columns: {'plan_precios_cuidados', 'stock_final_lag_23'}
# Step DeleteBadColumns completed in 1.15 seconds
# Executing step: FilterProductsIDStep
# Filtered DataFrame df shape: (128417, 219)
# Step FilterProductsIDStep completed in 0.20 seconds
# Executing step: SplitDataFrameStep2
# Step SplitDataFrameStep2 completed in 0.05 seconds
# Executing step: PrepareXYStep
# X_train indexes: Index([       0,       36,       72,      108,      144,      180,      216,
#             252,      288,      324,
#        ...
#        12902100, 12902131, 12902179, 12902214, 12902271, 12902310, 12902365,
#        12902399, 12902489, 12902548],
#       dtype='int64', length=83019)
# (128417, 219)
# Step PrepareXYStep completed in 0.21 seconds
# Executing step: TrainModelStep
# Validation set size: 5302
# X_eval first 5 rows:
#      product_id  customer_id  cust_request_qty  cust_request_tn        tn  \
# 29        20001        10001                 7          65.9375   65.9375
# 65        20001        10002                19         178.5000  144.1250
# 101       20001        10003                 0           0.0000    0.0000
# 137       20001        10004                15          66.7500   66.7500
# 173       20001        10005                 0           0.0000    0.0000
#
#      stock_final cat1         cat2     cat3  brand  ...  \
# 29         519.5   HC  ROPA LAVADO  Liquido  ARIEL  ...
# 65         519.5   HC  ROPA LAVADO  Liquido  ARIEL  ...
# 101          NaN   HC  ROPA LAVADO  Liquido  ARIEL  ...
# 137        519.5   HC  ROPA LAVADO  Liquido  ARIEL  ...
# 173          NaN   HC  ROPA LAVADO  Liquido  ARIEL  ...
#
#      tn_div_tn_cat1_vendidas  tn_div_tn_cat2_vendidas  \
# 29                  0.036530                 0.037811
# 65                  0.079834                 0.082703
# 101                 0.000000                 0.000000
# 137                 0.036987                 0.038300
# 173                 0.000000                 0.000000
#
#      tn_div_tn_cat3_vendidas  tn_div_tn_brand_vendidas  \
# 29                  0.047668                  0.036530
# 65                  0.104187                  0.079834
# 101                 0.000000                  0.000000
# 137                 0.048248                  0.036987
# 173                 0.000000                  0.000000
#
#      tn_prod_cust_request_qty  tn_customer_vendidas  tn_total_vendidas  \
# 29                      461.5            158.750000             1805.0
# 65                     2738.0            205.125000             1805.0
# 101                       0.0             58.687500             1805.0
# 137                    1001.0             92.937500             1805.0
# 173                       0.0              6.101562             1805.0
#
#      customer_weight  tn_product_vendidas  product_weight
# 29          0.087952               1110.0        0.614746
# 65          0.113647               1110.0        0.614746
# 101         0.032501               1110.0        0.614746
# 137         0.051483               1110.0        0.614746
# 173         0.003380               1110.0        0.614746
#
# [5 rows x 217 columns]
# y_eval first 5 rows:
#        target
# 29  -232.3750
# 65   -46.8750
# 101   41.0625
# 137 -104.4375
# 173  -16.4375
# /home/fede/.venvs/labo3/lib/python3.12/site-packages/pandas/io/formats/format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
# /home/fede/.venvs/labo3/lib/python3.12/site-packages/pandas/io/formats/format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
# [100]	valid_0's l2: 17.1568	valid_0's total_error: 1.22799
# [200]	valid_0's l2: 16.1556	valid_0's total_error: 1.11825
# [300]	valid_0's l2: 15.5443	valid_0's total_error: 1.06357
# [400]	valid_0's l2: 15.6537	valid_0's total_error: 1.04697
# [500]	valid_0's l2: 15.6319	valid_0's total_error: 1.04724
# [600]	valid_0's l2: 15.5351	valid_0's total_error: 1.02532
# [700]	valid_0's l2: 15.7062	valid_0's total_error: 0.978477
# [800]	valid_0's l2: 15.5221	valid_0's total_error: 0.963123
# [900]	valid_0's l2: 15.482	valid_0's total_error: 1.00196
# [1000]	valid_0's l2: 15.3084	valid_0's total_error: 0.987926
# [1100]	valid_0's l2: 15.3274	valid_0's total_error: 0.989223
# [1200]	valid_0's l2: 15.2276	valid_0's total_error: 0.994576
# [1300]	valid_0's l2: 15.0462	valid_0's total_error: 0.975038
# [1400]	valid_0's l2: 15.104	valid_0's total_error: 0.970402
# [1500]	valid_0's l2: 15.236	valid_0's total_error: 0.990322
# Step TrainModelStep completed in 30.89 seconds
# Executing step: PredictStep
# Step PredictStep completed in 0.38 seconds
# Executing step: InverseResidualTargetStep
# /tmp/ipykernel_98974/3669324445.py:148: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['base_prediction'] = (
# Step InverseResidualTargetStep completed in 1.38 seconds
# Executing step: InverseScalePredictionsStep
# Step InverseScalePredictionsStep completed in 0.02 seconds
# Executing step: IntegratePredictionsStep
# Step IntegratePredictionsStep completed in 0.02 seconds
# Executing step: EvaluatePredictionsSteps
# Error en test: 0.2849
#
# Top 5 productos con mayor error absoluto:
#    product_id       target  predictions      tn_real      tn_pred  \
# 0       20001  1261.322642  1515.850805  1261.322642  1515.850805
# 1       20045   115.114431   183.234329   115.114431   183.234329
# 7       20649    11.354645    75.591061    11.354645    75.591061
# 9       20691    23.896790    56.474383    23.896790    56.474383
# 4       20150    68.611140    88.441539    68.611140    88.441539
#
#    error_absoluto
# 0      254.528162
# 1       68.119897
# 7       64.236416
# 9       32.577593
# 4       19.830400
# Step EvaluatePredictionsSteps completed in 0.03 seconds
# Executing step: EvaluatePredictionsOptimizatedSteps
# alfa optimizado: 0.8421
# Error en train: 0.0653
# Error en test: 0.2105
#
# Top 5 productos con mayor error absoluto en train:
#    product_id     target  predictions    tn_real    tn_pred  error_absoluto
# 7       20649   6.374329    26.900510   6.374329  26.900510       20.526182
# 9       20691  18.834442    26.780384  18.834442  26.780384        7.945942
# 1       20045  76.073653    68.579567  76.073653  68.579567        7.494086
# 2       20102   4.279672    11.508826   4.279672  11.508826        7.229154
# 4       20150  44.905400    52.010295  44.905400  52.010295        7.104894
#
# Top 5 productos con mayor error absoluto en test:
#    product_id      target  predictions     tn_real     tn_pred  error_absoluto
# 1       20045   39.040778    85.718216   39.040778   85.718216       46.677438
# 7       20649    4.980316    36.753136    4.980316   36.753136       31.772820
# 3       20135   48.795526    27.751226   48.795526   27.751226       21.044299
# 9       20691    5.062347    20.775509    5.062347   20.775509       15.713161
# 0       20001  525.429613   540.573127  525.429613  540.573127       15.143514
# Step EvaluatePredictionsOptimizatedSteps completed in 0.44 seconds
# Processing brand: LIMPIEX
# Executing step: LoadDataFrameStep
# Step LoadDataFrameStep completed in 2.59 seconds
# Executing step: DateRelatedFeaturesStep
# Step DateRelatedFeaturesStep completed in 5.22 seconds
# Executing step: FilterDatasetByColumn
# (914398, 17)
# Step FilterDatasetByColumn completed in 2.78 seconds
# Executing step: CreateResidualTargetStep
# Step CreateResidualTargetStep completed in 6.25 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 74.12 MB
# --- Memory usage after: 36.63 MB
# --- Decreased memory usage by 50.6%
#
# Step ReduceMemoryUsageStep completed in 0.14 seconds
# Executing step: FeatureEngineeringLagStep
# Step FeatureEngineeringLagStep completed in 0.36 seconds
# Executing step: RollingMeanFeatureStep
# Step RollingMeanFeatureStep completed in 17.27 seconds
# Executing step: RollingMaxFeatureStep
# Step RollingMaxFeatureStep completed in 16.54 seconds
# Executing step: RollingMinFeatureStep
# Step RollingMinFeatureStep completed in 16.45 seconds
# Executing step: RollingMeanFeatureStep
# Step RollingMeanFeatureStep completed in 17.42 seconds
# Executing step: RollingMaxFeatureStep
# Step RollingMaxFeatureStep completed in 16.83 seconds
# Executing step: RollingMinFeatureStep
# Step RollingMinFeatureStep completed in 16.73 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 224.99 MB
# --- Memory usage after: 99.41 MB
# --- Decreased memory usage by 55.8%
#
# Step ReduceMemoryUsageStep completed in 0.82 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 12.84 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 13.12 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 12.83 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 13.62 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 13.40 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 13.31 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 183.13 MB
# --- Memory usage after: 120.34 MB
# --- Decreased memory usage by 34.3%
#
# Step ReduceMemoryUsageStep completed in 1.05 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 24.04 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 24.42 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 26.23 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.48 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.56 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.60 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.62 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.65 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.69 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#      date_id   cat1            tn
# 0          0  FOODS   6490.774902
# 1          0     HC  20304.287109
# 2          0     PC   7183.233887
# 3          0    REF      8.984159
# 4          1  FOODS   7096.089844
# ..       ...    ...           ...
# 139       34    REF      0.470640
# 140       35  FOODS   4907.414551
# 141       35     HC  16045.644531
# 142       35     PC   5263.639160
# 143       35    REF      0.368930
#
# [144 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 1.70 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#      date_id            cat2           tn
# 0          0        ADEREZOS  4844.348145
# 1          0         CABELLO  4586.802246
# 2          0          DENTAL     1.525830
# 3          0            DEOS  1178.932739
# 4          0           HOGAR  2795.374268
# ..       ...             ...          ...
# 535       35     ROPA LAVADO  9541.868164
# 536       35    ROPA MANCHAS   207.274765
# 537       35  SOPAS Y CALDOS   722.231995
# 538       35              TE     0.368930
# 539       35         VAJILLA  2469.144287
#
# [540 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 1.82 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#       date_id              cat3           tn
# 0           0    ACONDICIONADOR  3565.031982
# 1           0        Acond Bebe     0.000000
# 2           0       Acond Mujer   245.138306
# 3           0              Aero   795.659119
# 4           0       Aji Picante     6.321310
# ...       ...               ...          ...
# 3343       35    Toallitas Bebe     5.400110
# 3344       35   Tratamiento Fem     3.135710
# 3345       35  Tratamiento Masc     4.049170
# 3346       35             Verde     0.034220
# 3347       35           Vidrios   230.734436
#
# [3348 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 2.55 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 2.10 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 1.80 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 1.72 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 1.71 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 1.89 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 1.85 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 1.76 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 1.77 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 1.81 seconds
# Executing step: FeatureDivInteractionStep
# Step FeatureDivInteractionStep completed in 1.40 seconds
# Executing step: FeatureProdInteractionStep
# Step FeatureProdInteractionStep completed in 1.43 seconds
# Executing step: CreateWeightByCustomerStep
# Step CreateWeightByCustomerStep completed in 2.07 seconds
# Executing step: CreateWeightByProductStep
# Step CreateWeightByProductStep completed in 1.96 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 659.26 MB
# --- Memory usage after: 395.91 MB
# --- Decreased memory usage by 39.9%
#
# Step ReduceMemoryUsageStep completed in 9.00 seconds
# Executing step: DeleteBadColumns
# Deleted columns: {'stock_final_lag_23'}
# Step DeleteBadColumns completed in 9.32 seconds
# Executing step: FilterProductsIDStep
# Filtered DataFrame df shape: (706941, 220)
# Step FilterProductsIDStep completed in 5.07 seconds
# Executing step: SplitDataFrameStep2
# Step SplitDataFrameStep2 completed in 0.46 seconds
# Executing step: PrepareXYStep
# X_train indexes: Index([  17862,   17898,   17934,   17970,   18006,   18042,   18078,   18114,
#          18150,   18186,
#        ...
#        9409836, 9409841, 9409851, 9409861, 9409866, 9409876, 9409888, 9409898,
#        9409917, 9409930],
#       dtype='int64', length=529735)
# (706941, 220)
# Step PrepareXYStep completed in 1.47 seconds
# Executing step: TrainModelStep
# Validation set size: 21690
# X_eval first 5 rows:
#        product_id  customer_id  plan_precios_cuidados  cust_request_qty  \
# 17891       20002        10001                    0.0                24
# 17927       20002        10002                    0.0                10
# 17963       20002        10003                    0.0                21
# 17999       20002        10004                    0.0                 9
# 18035       20002        10005                    0.0                 0
#
#        cust_request_tn          tn  stock_final cat1         cat2     cat3  \
# 17891       154.125000  151.125000       483.25   HC  ROPA LAVADO  Liquido
# 17927        23.921875   20.984375       483.25   HC  ROPA LAVADO  Liquido
# 17963        55.750000   55.750000       483.25   HC  ROPA LAVADO  Liquido
# 17999        94.312500   94.312500       483.25   HC  ROPA LAVADO  Liquido
# 18035         0.000000    0.000000          NaN   HC  ROPA LAVADO  Liquido
#
#        ... tn_div_tn_cat1_vendidas  tn_div_tn_cat2_vendidas  \
# 17891  ...                0.018295                 0.027588
# 17927  ...                0.002541                 0.003832
# 17963  ...                0.006748                 0.010178
# 17999  ...                0.011414                 0.017227
# 18035  ...                0.000000                 0.000000
#
#        tn_div_tn_cat3_vendidas  tn_div_tn_brand_vendidas  \
# 17891                 0.092834                  0.018295
# 17927                 0.012886                  0.002541
# 17963                 0.034241                  0.006748
# 17999                 0.057922                  0.011414
# 18035                 0.000000                  0.000000
#
#        tn_prod_cust_request_qty  tn_customer_vendidas  tn_total_vendidas  \
# 17891                  3628.000               404.250             8264.0
# 17927                   209.875               876.500             8264.0
# 17963                  1171.000               239.375             8264.0
# 17999                   849.000               187.500             8264.0
# 18035                     0.000               726.500             8264.0
#
#        customer_weight  tn_product_vendidas  product_weight
# 17891         0.048920                928.5        0.112366
# 17927         0.106079                928.5        0.112366
# 17963         0.028961                928.5        0.112366
# 17999         0.022690                928.5        0.112366
# 18035         0.087891                928.5        0.112366
#
# [5 rows x 218 columns]
# y_eval first 5 rows:
#            target
# 17891  -65.875000
# 17927  -25.375000
# 17963    8.773438
# 17999 -105.375000
# 18035  -19.984375
# /home/fede/.venvs/labo3/lib/python3.12/site-packages/pandas/io/formats/format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
# /home/fede/.venvs/labo3/lib/python3.12/site-packages/pandas/io/formats/format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
# [100]	valid_0's l2: 3.78856	valid_0's total_error: 0.907035
# [200]	valid_0's l2: 3.75078	valid_0's total_error: 0.913153
# [300]	valid_0's l2: 3.77037	valid_0's total_error: 0.91117
# [400]	valid_0's l2: 3.79293	valid_0's total_error: 0.903135
# [500]	valid_0's l2: 3.81633	valid_0's total_error: 0.903273
# [600]	valid_0's l2: 3.79109	valid_0's total_error: 0.893877
# [700]	valid_0's l2: 3.81373	valid_0's total_error: 0.89109
# [800]	valid_0's l2: 3.8415	valid_0's total_error: 0.889429
# [900]	valid_0's l2: 3.80857	valid_0's total_error: 0.88079
# [1000]	valid_0's l2: 3.81585	valid_0's total_error: 0.876896
# [1100]	valid_0's l2: 3.80188	valid_0's total_error: 0.86887
# [1200]	valid_0's l2: 3.77001	valid_0's total_error: 0.862312
# [1300]	valid_0's l2: 3.78262	valid_0's total_error: 0.86417
# [1400]	valid_0's l2: 3.80267	valid_0's total_error: 0.867376
# [1500]	valid_0's l2: 3.78441	valid_0's total_error: 0.865198
# Step TrainModelStep completed in 141.55 seconds
# Executing step: PredictStep
# Step PredictStep completed in 0.77 seconds
# Executing step: InverseResidualTargetStep
# /tmp/ipykernel_98974/3669324445.py:148: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['base_prediction'] = (
# Step InverseResidualTargetStep completed in 5.72 seconds
# Executing step: InverseScalePredictionsStep
# Step InverseScalePredictionsStep completed in 0.07 seconds
# Executing step: IntegratePredictionsStep
# Step IntegratePredictionsStep completed in 0.09 seconds
# Executing step: EvaluatePredictionsSteps
# Error en test: 0.4792
#
# Top 5 productos con mayor error absoluto:
#    product_id      target  predictions     tn_real      tn_pred  \
# 0       20002  813.761120  1152.078789  813.761120  1152.078789
# 2       20008  233.032150   476.626856  233.032150   476.626856
# 1       20006  262.751018   481.257253  262.751018   481.257253
# 3       20010  199.851811   405.018733  199.851811   405.018733
# 7       20018  127.573596   299.496817  127.573596   299.496817
#
#    error_absoluto
# 0      338.317669
# 2      243.594707
# 1      218.506236
# 3      205.166922
# 7      171.923221
# Step EvaluatePredictionsSteps completed in 0.14 seconds
# Executing step: EvaluatePredictionsOptimizatedSteps
# alfa optimizado: 0.7463
# Error en train: 0.3138
# Error en test: 0.3747
#
# Top 5 productos con mayor error absoluto en train:
#     product_id      target  predictions     tn_real     tn_pred  \
# 1        20006   75.789793   177.072268   75.789793  177.072268
# 0        20002  593.298390   506.026741  593.298390  506.026741
# 2        20008   69.701094   141.358690   69.701094  141.358690
# 12       20025  152.765032    86.997185  152.765032   86.997185
# 7        20018   63.888690   124.289365   63.888690  124.289365
#
#     error_absoluto
# 1       101.282476
# 0        87.271648
# 2        71.657596
# 12       65.767847
# 7        60.400675
#
# Top 5 productos con mayor error absoluto en test:
#     product_id      target  predictions     tn_real     tn_pred  \
# 0        20002  220.462731   353.793303  220.462731  353.793303
# 3        20010   80.793676   161.213227   80.793676  161.213227
# 5        20016   66.236631   123.469893   66.236631  123.469893
# 10       20022  133.218957    76.612706  133.218957   76.612706
# 8        20020  129.083460    76.039458  129.083460   76.039458
#
#     error_absoluto
# 0       133.330572
# 3        80.419551
# 5        57.233262
# 10       56.606250
# 8        53.044002
# Step EvaluatePredictionsOptimizatedSteps completed in 0.42 seconds
# Processing brand: NATURA
# Executing step: LoadDataFrameStep
# Step LoadDataFrameStep completed in 1.97 seconds
# Executing step: DateRelatedFeaturesStep
# Step DateRelatedFeaturesStep completed in 4.91 seconds
# Executing step: FilterDatasetByColumn
# (635578, 17)
# Step FilterDatasetByColumn completed in 2.67 seconds
# Executing step: CreateResidualTargetStep
# Step CreateResidualTargetStep completed in 4.16 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 51.52 MB
# --- Memory usage after: 25.46 MB
# --- Decreased memory usage by 50.6%
#
# Step ReduceMemoryUsageStep completed in 0.10 seconds
# Executing step: FeatureEngineeringLagStep
# Step FeatureEngineeringLagStep completed in 0.26 seconds
# Executing step: RollingMeanFeatureStep
# Step RollingMeanFeatureStep completed in 12.01 seconds
# Executing step: RollingMaxFeatureStep
# Step RollingMaxFeatureStep completed in 11.45 seconds
# Executing step: RollingMinFeatureStep
# Step RollingMinFeatureStep completed in 11.35 seconds
# Executing step: RollingMeanFeatureStep
# Step RollingMeanFeatureStep completed in 11.98 seconds
# Executing step: RollingMaxFeatureStep
# Step RollingMaxFeatureStep completed in 11.57 seconds
# Executing step: RollingMinFeatureStep
# Step RollingMinFeatureStep completed in 11.66 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 156.38 MB
# --- Memory usage after: 69.10 MB
# --- Decreased memory usage by 55.8%
#
# Step ReduceMemoryUsageStep completed in 0.59 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 9.47 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 9.04 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 9.66 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 9.17 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 9.00 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 9.45 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 127.29 MB
# --- Memory usage after: 83.65 MB
# --- Decreased memory usage by 34.3%
#
# Step ReduceMemoryUsageStep completed in 0.72 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 17.43 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 17.80 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 17.66 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.30 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.34 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.35 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.36 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.35 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.38 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#      date_id   cat1            tn
# 0          0  FOODS   6490.774902
# 1          0     HC  20304.287109
# 2          0     PC   7183.233887
# 3          0    REF      8.984159
# 4          1  FOODS   7096.089844
# ..       ...    ...           ...
# 139       34    REF      0.470640
# 140       35  FOODS   4907.414551
# 141       35     HC  16045.644531
# 142       35     PC   5263.639160
# 143       35    REF      0.368930
#
# [144 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 1.48 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#      date_id            cat2           tn
# 0          0        ADEREZOS  4844.348145
# 1          0         CABELLO  4586.802246
# 2          0          DENTAL     1.525830
# 3          0            DEOS  1178.932739
# 4          0           HOGAR  2795.374268
# ..       ...             ...          ...
# 535       35     ROPA LAVADO  9541.868164
# 536       35    ROPA MANCHAS   207.274765
# 537       35  SOPAS Y CALDOS   722.231995
# 538       35              TE     0.368930
# 539       35         VAJILLA  2469.144287
#
# [540 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 1.41 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#       date_id              cat3           tn
# 0           0    ACONDICIONADOR  3565.031982
# 1           0        Acond Bebe     0.000000
# 2           0       Acond Mujer   245.138306
# 3           0              Aero   795.659119
# 4           0       Aji Picante     6.321310
# ...       ...               ...          ...
# 3343       35    Toallitas Bebe     5.400110
# 3344       35   Tratamiento Fem     3.135710
# 3345       35  Tratamiento Masc     4.049170
# 3346       35             Verde     0.034220
# 3347       35           Vidrios   230.734436
#
# [3348 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 2.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 1.35 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 1.18 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 1.18 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 1.16 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 1.28 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 1.30 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 1.17 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 1.26 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 1.22 seconds
# Executing step: FeatureDivInteractionStep
# Step FeatureDivInteractionStep completed in 0.97 seconds
# Executing step: FeatureProdInteractionStep
# Step FeatureProdInteractionStep completed in 0.92 seconds
# Executing step: CreateWeightByCustomerStep
# Step CreateWeightByCustomerStep completed in 1.30 seconds
# Executing step: CreateWeightByProductStep
# Step CreateWeightByProductStep completed in 1.31 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 458.24 MB
# --- Memory usage after: 275.19 MB
# --- Decreased memory usage by 39.9%
#
# Step ReduceMemoryUsageStep completed in 2.16 seconds
# Executing step: DeleteBadColumns
# Deleted columns: {'plan_precios_cuidados', 'stock_final_lag_23'}
# Step DeleteBadColumns completed in 2.00 seconds
# Executing step: FilterProductsIDStep
# Filtered DataFrame df shape: (428136, 219)
# Step FilterProductsIDStep completed in 0.58 seconds
# Executing step: SplitDataFrameStep2
# Step SplitDataFrameStep2 completed in 0.19 seconds
# Executing step: PrepareXYStep
# X_train indexes: Index([  35724,   35760,   35796,   35832,   35868,   35904,   35940,   35976,
#          36012,   36048,
#        ...
#        9295620, 9295651, 9295699, 9295734, 9295791, 9295830, 9295885, 9295919,
#        9296009, 9296068],
#       dtype='int64', length=318556)
# (428136, 219)
# Step PrepareXYStep completed in 0.76 seconds
# Executing step: TrainModelStep
# Validation set size: 13014
# X_eval first 5 rows:
#        product_id  customer_id  cust_request_qty  cust_request_tn          tn  \
# 35753       20003        10001                14        78.812500   78.812500
# 35789       20003        10002                13       141.000000  133.125000
# 35825       20003        10003                 2        24.890625   24.890625
# 35861       20003        10004                 4        51.656250   51.656250
# 35897       20003        10005                21        11.101562   11.101562
#
#        stock_final   cat1      cat2      cat3   brand  ...  \
# 35753        512.5  FOODS  ADEREZOS  Mayonesa  NATURA  ...
# 35789        512.5  FOODS  ADEREZOS  Mayonesa  NATURA  ...
# 35825        512.5  FOODS  ADEREZOS  Mayonesa  NATURA  ...
# 35861        512.5  FOODS  ADEREZOS  Mayonesa  NATURA  ...
# 35897        512.5  FOODS  ADEREZOS  Mayonesa  NATURA  ...
#
#        tn_div_tn_cat1_vendidas  tn_div_tn_cat2_vendidas  \
# 35753                 0.024597                 0.024597
# 35789                 0.041565                 0.041565
# 35825                 0.007771                 0.007771
# 35861                 0.016129                 0.016129
# 35897                 0.003466                 0.003466
#
#        tn_div_tn_cat3_vendidas  tn_div_tn_brand_vendidas  \
# 35753                 0.028183                  0.024597
# 35789                 0.047577                  0.041565
# 35825                 0.008896                  0.007771
# 35861                 0.018463                  0.016129
# 35897                 0.003967                  0.003466
#
#        tn_prod_cust_request_qty  tn_customer_vendidas  tn_total_vendidas  \
# 35753                1103.00000              204.8750             3204.0
# 35789                1731.00000              513.5000             3204.0
# 35825                  49.78125               72.8750             3204.0
# 35861                 206.62500              104.1875             3204.0
# 35897                 233.12500              102.0625             3204.0
#
#        customer_weight  tn_product_vendidas  product_weight
# 35753         0.063965                662.5        0.206787
# 35789         0.160278                662.5        0.206787
# 35825         0.022766                662.5        0.206787
# 35861         0.032532                662.5        0.206787
# 35897         0.031860                662.5        0.206787
#
# [5 rows x 217 columns]
# y_eval first 5 rows:
#           target
# 35753  18.515625
# 35789 -60.781250
# 35825  -1.245117
# 35861 -56.218750
# 35897 -22.218750
# /home/fede/.venvs/labo3/lib/python3.12/site-packages/pandas/io/formats/format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
# /home/fede/.venvs/labo3/lib/python3.12/site-packages/pandas/io/formats/format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
# [100]	valid_0's l2: 1.81916	valid_0's total_error: 0.860185
# [200]	valid_0's l2: 1.7694	valid_0's total_error: 0.813957
# [300]	valid_0's l2: 1.73532	valid_0's total_error: 0.76217
# [400]	valid_0's l2: 1.72236	valid_0's total_error: 0.7249
# [500]	valid_0's l2: 1.75941	valid_0's total_error: 0.718328
# [600]	valid_0's l2: 1.77191	valid_0's total_error: 0.695597
# [700]	valid_0's l2: 1.76746	valid_0's total_error: 0.683267
# [800]	valid_0's l2: 1.77685	valid_0's total_error: 0.68315
# [900]	valid_0's l2: 1.77099	valid_0's total_error: 0.678503
# [1000]	valid_0's l2: 1.79585	valid_0's total_error: 0.665271
# [1100]	valid_0's l2: 1.81978	valid_0's total_error: 0.660034
# [1200]	valid_0's l2: 1.81451	valid_0's total_error: 0.648954
# [1300]	valid_0's l2: 1.82449	valid_0's total_error: 0.639228
# [1400]	valid_0's l2: 1.81833	valid_0's total_error: 0.631113
# [1500]	valid_0's l2: 1.8139	valid_0's total_error: 0.627591
# Step TrainModelStep completed in 59.29 seconds
# Executing step: PredictStep
# Step PredictStep completed in 0.61 seconds
# Executing step: InverseResidualTargetStep
# /tmp/ipykernel_98974/3669324445.py:148: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['base_prediction'] = (
# Step InverseResidualTargetStep completed in 3.44 seconds
# Executing step: InverseScalePredictionsStep
# Step InverseScalePredictionsStep completed in 0.04 seconds
# Executing step: IntegratePredictionsStep
# Step IntegratePredictionsStep completed in 0.05 seconds
# Executing step: EvaluatePredictionsSteps
# Error en test: 0.1800
#
# Top 5 productos con mayor error absoluto:
#    product_id      target  predictions     tn_real     tn_pred  error_absoluto
# 1       20004  482.038922   593.594712  482.038922  593.594712      111.555790
# 9       20119  165.810220    74.266432  165.810220   74.266432       91.543789
# 3       20019  231.815264   306.862243  231.815264  306.862243       75.046979
# 0       20003  635.607411   700.496438  635.607411  700.496438       64.889026
# 4       20033  224.326797   178.948073  224.326797  178.948073       45.378723
# Step EvaluatePredictionsSteps completed in 0.06 seconds
# Executing step: EvaluatePredictionsOptimizatedSteps
# alfa optimizado: 0.9310
# Error en train: 0.1486
# Error en test: 0.1618
#
# Top 5 productos con mayor error absoluto en train:
#    product_id      target  predictions     tn_real     tn_pred  error_absoluto
# 9       20119  117.123404    46.554015  117.123404   46.554015       70.569389
# 3       20019  154.422118   189.108103  154.422118  189.108103       34.685985
# 5       20046   99.925434    65.988192   99.925434   65.988192       33.937241
# 4       20033  109.785159    80.697402  109.785159   80.697402       29.087757
# 1       20004  224.248601   237.811843  224.248601  237.811843       13.563242
#
# Top 5 productos con mayor error absoluto en test:
#    product_id      target  predictions     tn_real     tn_pred  error_absoluto
# 1       20004  257.790321   314.842116  257.790321  314.842116       57.051795
# 4       20033  114.541637    85.908464  114.541637   85.908464       28.633173
# 9       20119   48.686816    22.590195   48.686816   22.590195       26.096621
# 6       20095   67.634119    44.831624   67.634119   44.831624       22.802495
# 3       20019   77.393146    96.589579   77.393146   96.589579       19.196433
# Step EvaluatePredictionsOptimizatedSteps completed in 0.26 seconds
# Processing brand: DOWNY
# Executing step: LoadDataFrameStep
# Step LoadDataFrameStep completed in 2.06 seconds
# Executing step: DateRelatedFeaturesStep
# Step DateRelatedFeaturesStep completed in 5.05 seconds
# Executing step: FilterDatasetByColumn
# (272431, 17)
# Step FilterDatasetByColumn completed in 2.64 seconds
# Executing step: CreateResidualTargetStep
# Step CreateResidualTargetStep completed in 1.92 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 22.09 MB
# --- Memory usage after: 10.91 MB
# --- Decreased memory usage by 50.6%
#
# Step ReduceMemoryUsageStep completed in 0.04 seconds
# Executing step: FeatureEngineeringLagStep
# Step FeatureEngineeringLagStep completed in 0.11 seconds
# Executing step: RollingMeanFeatureStep
# Step RollingMeanFeatureStep completed in 4.97 seconds
# Executing step: RollingMaxFeatureStep
# Step RollingMaxFeatureStep completed in 4.80 seconds
# Executing step: RollingMinFeatureStep
# Step RollingMinFeatureStep completed in 5.01 seconds
# Executing step: RollingMeanFeatureStep
# Step RollingMeanFeatureStep completed in 5.52 seconds
# Executing step: RollingMaxFeatureStep
# Step RollingMaxFeatureStep completed in 5.18 seconds
# Executing step: RollingMinFeatureStep
# Step RollingMinFeatureStep completed in 5.09 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 67.03 MB
# --- Memory usage after: 29.62 MB
# --- Decreased memory usage by 55.8%
#
# Step ReduceMemoryUsageStep completed in 0.26 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 3.62 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 3.78 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 3.78 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 3.70 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 3.70 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 3.84 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 54.56 MB
# --- Memory usage after: 35.85 MB
# --- Decreased memory usage by 34.3%
#
# Step ReduceMemoryUsageStep completed in 0.31 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 6.78 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 6.95 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 6.76 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.12 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.13 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.13 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.13 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.14 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.15 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#      date_id   cat1            tn
# 0          0  FOODS   6490.774902
# 1          0     HC  20304.287109
# 2          0     PC   7183.233887
# 3          0    REF      8.984159
# 4          1  FOODS   7096.089844
# ..       ...    ...           ...
# 139       34    REF      0.470640
# 140       35  FOODS   4907.414551
# 141       35     HC  16045.644531
# 142       35     PC   5263.639160
# 143       35    REF      0.368930
#
# [144 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 1.06 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#      date_id            cat2           tn
# 0          0        ADEREZOS  4844.348145
# 1          0         CABELLO  4586.802246
# 2          0          DENTAL     1.525830
# 3          0            DEOS  1178.932739
# 4          0           HOGAR  2795.374268
# ..       ...             ...          ...
# 535       35     ROPA LAVADO  9541.868164
# 536       35    ROPA MANCHAS   207.274765
# 537       35  SOPAS Y CALDOS   722.231995
# 538       35              TE     0.368930
# 539       35         VAJILLA  2469.144287
#
# [540 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 1.12 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#       date_id              cat3           tn
# 0           0    ACONDICIONADOR  3565.031982
# 1           0        Acond Bebe     0.000000
# 2           0       Acond Mujer   245.138306
# 3           0              Aero   795.659119
# 4           0       Aji Picante     6.321310
# ...       ...               ...          ...
# 3343       35    Toallitas Bebe     5.400110
# 3344       35   Tratamiento Fem     3.135710
# 3345       35  Tratamiento Masc     4.049170
# 3346       35             Verde     0.034220
# 3347       35           Vidrios   230.734436
#
# [3348 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 1.36 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.55 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.44 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.42 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.48 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.45 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.45 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.44 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.44 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.45 seconds
# Executing step: FeatureDivInteractionStep
# Step FeatureDivInteractionStep completed in 0.34 seconds
# Executing step: FeatureProdInteractionStep
# Step FeatureProdInteractionStep completed in 0.37 seconds
# Executing step: CreateWeightByCustomerStep
# Step CreateWeightByCustomerStep completed in 0.56 seconds
# Executing step: CreateWeightByProductStep
# Step CreateWeightByProductStep completed in 0.51 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 196.42 MB
# --- Memory usage after: 117.96 MB
# --- Decreased memory usage by 39.9%
#
# Step ReduceMemoryUsageStep completed in 0.94 seconds
# Executing step: DeleteBadColumns
# Deleted columns: {'stock_final_lag_23'}
# Step DeleteBadColumns completed in 0.70 seconds
# Executing step: FilterProductsIDStep
# Filtered DataFrame df shape: (222820, 220)
# Step FilterProductsIDStep completed in 0.26 seconds
# Executing step: SplitDataFrameStep2
# Step SplitDataFrameStep2 completed in 0.11 seconds
# Executing step: PrepareXYStep
# X_train indexes: Index([  107172,   107208,   107244,   107280,   107316,   107352,   107388,
#          107424,   107460,   107496,
#        ...
#        10792850, 10792881, 10792929, 10792964, 10793021, 10793060, 10793115,
#        10793149, 10793239, 10793298],
#       dtype='int64', length=171483)
# (222820, 220)
# ...
# /tmp/ipykernel_98974/3669324445.py:148: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['base_prediction'] = (
# Step InverseResidualTargetStep completed in 0.75 seconds
# Executing step: InverseScalePredictionsStep
# Step InverseScalePredictionsStep completed in 0.01 seconds
# Executing step: IntegratePredictionsStep
# Step IntegratePredictionsStep completed in 0.01 seconds
# Executing step: EvaluatePredictionsSteps
# Error en test: 0.4291
#
# Top 5 productos con mayor error absoluto:
#    product_id    target  predictions   tn_real   tn_pred  error_absoluto
# 5       21245  0.068272     0.223186  0.068272  0.223186        0.154914
# 0       21142  0.602781     0.512461  0.602781  0.512461        0.090320
# 4       21233  0.079804     0.158948  0.079804  0.158948        0.079144
# 1       21191  0.146995     0.215604  0.146995  0.215604        0.068609
# 3       21226  0.147976     0.213291  0.147976  0.213291        0.065315
# Step EvaluatePredictionsSteps completed in 0.02 seconds
# Executing step: EvaluatePredictionsOptimizatedSteps
# alfa optimizado: 0.8434
# Error en train: 0.2872
# Error en test: 0.5489
#
# Top 5 productos con mayor error absoluto en train:
#    product_id    target  predictions   tn_real   tn_pred  error_absoluto
# 5       21245  0.022141     0.117695  0.022141  0.117695        0.095555
# 0       21142  0.395306     0.300066  0.395306  0.300066        0.095240
# 1       21191  0.110247     0.125081  0.110247  0.125081        0.014835
# 2       21209  0.111926     0.119709  0.111926  0.119709        0.007783
# 4       21233  0.010590     0.004401  0.010590  0.004401        0.006188
#
# Top 5 productos con mayor error absoluto en test:
#    product_id    target  predictions   tn_real   tn_pred  error_absoluto
# 0       21142  0.207475     0.132156  0.207475  0.132156        0.075319
# 4       21233  0.069214     0.129659  0.069214  0.129659        0.060445
# 3       21226  0.033589     0.065507  0.033589  0.065507        0.031918
# 5       21245  0.046131     0.070545  0.046131  0.070545        0.024414
# 1       21191  0.036748     0.056764  0.036748  0.056764        0.020016
# Step EvaluatePredictionsOptimizatedSteps completed in 0.34 seconds
# Processing brand: VICHY
# Executing step: LoadDataFrameStep
# Step LoadDataFrameStep completed in 2.01 seconds
# Executing step: DateRelatedFeaturesStep
# Step DateRelatedFeaturesStep completed in 4.89 seconds
# Executing step: FilterDatasetByColumn
# (58948, 17)
# Step FilterDatasetByColumn completed in 2.57 seconds
# Executing step: CreateResidualTargetStep
# Step CreateResidualTargetStep completed in 0.70 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 4.78 MB
# --- Memory usage after: 2.36 MB
# --- Decreased memory usage by 50.6%
#
# Step ReduceMemoryUsageStep completed in 0.01 seconds
# Executing step: FeatureEngineeringLagStep
# Step FeatureEngineeringLagStep completed in 0.03 seconds
# Executing step: RollingMeanFeatureStep
# Step RollingMeanFeatureStep completed in 2.24 seconds
# Executing step: RollingMaxFeatureStep
# Step RollingMaxFeatureStep completed in 2.19 seconds
# Executing step: RollingMinFeatureStep
# Step RollingMinFeatureStep completed in 2.10 seconds
# Executing step: RollingMeanFeatureStep
# Step RollingMeanFeatureStep completed in 2.08 seconds
# Executing step: RollingMaxFeatureStep
# Step RollingMaxFeatureStep completed in 2.22 seconds
# Executing step: RollingMinFeatureStep
# Step RollingMinFeatureStep completed in 2.16 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 14.51 MB
# --- Memory usage after: 6.75 MB
# --- Decreased memory usage by 53.5%
#
# Step ReduceMemoryUsageStep completed in 0.06 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 1.80 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 1.59 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 1.58 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 1.68 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 1.64 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 1.67 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 12.14 MB
# --- Memory usage after: 8.10 MB
# --- Decreased memory usage by 33.3%
#
# Step ReduceMemoryUsageStep completed in 0.15 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 3.07 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 3.02 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 2.99 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.03 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.03 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.03 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.04 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.03 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.03 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#      date_id   cat1            tn
# 0          0  FOODS   6490.774902
# 1          0     HC  20304.287109
# 2          0     PC   7183.233887
# 3          0    REF      8.984159
# 4          1  FOODS   7096.089844
# ..       ...    ...           ...
# 139       34    REF      0.470640
# 140       35  FOODS   4907.414551
# 141       35     HC  16045.644531
# 142       35     PC   5263.639160
# 143       35    REF      0.368930
#
# [144 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 1.01 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#      date_id            cat2           tn
# 0          0        ADEREZOS  4844.348145
# 1          0         CABELLO  4586.802246
# 2          0          DENTAL     1.525830
# 3          0            DEOS  1178.932739
# 4          0           HOGAR  2795.374268
# ..       ...             ...          ...
# 535       35     ROPA LAVADO  9541.868164
# 536       35    ROPA MANCHAS   207.274765
# 537       35  SOPAS Y CALDOS   722.231995
# 538       35              TE     0.368930
# 539       35         VAJILLA  2469.144287
#
# [540 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 1.07 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#       date_id              cat3           tn
# 0           0    ACONDICIONADOR  3565.031982
# 1           0        Acond Bebe     0.000000
# 2           0       Acond Mujer   245.138306
# 3           0              Aero   795.659119
# 4           0       Aji Picante     6.321310
# ...       ...               ...          ...
# 3343       35    Toallitas Bebe     5.400110
# 3344       35   Tratamiento Fem     3.135710
# 3345       35  Tratamiento Masc     4.049170
# 3346       35             Verde     0.034220
# 3347       35           Vidrios   230.734436
#
# [3348 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 1.10 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.14 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.13 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.10 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.08 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.08 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.09 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.08 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.08 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.08 seconds
# Executing step: FeatureDivInteractionStep
# Step FeatureDivInteractionStep completed in 0.07 seconds
# Executing step: FeatureProdInteractionStep
# Step FeatureProdInteractionStep completed in 0.06 seconds
# Executing step: CreateWeightByCustomerStep
# Step CreateWeightByCustomerStep completed in 0.10 seconds
# Executing step: CreateWeightByProductStep
# Step CreateWeightByProductStep completed in 0.09 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 42.84 MB
# --- Memory usage after: 25.52 MB
# --- Decreased memory usage by 40.4%
#
# Step ReduceMemoryUsageStep completed in 0.40 seconds
# Executing step: DeleteBadColumns
# Deleted columns: {'plan_precios_cuidados', 'tn_lag_23', 'cust_request_qty_lag_23', 'stock_final_lag_23'}
# Step DeleteBadColumns completed in 0.16 seconds
# Executing step: FilterProductsIDStep
# Filtered DataFrame df shape: (52017, 217)
# Step FilterProductsIDStep completed in 0.07 seconds
# Executing step: SplitDataFrameStep2
# Step SplitDataFrameStep2 completed in 0.03 seconds
# Executing step: PrepareXYStep
# X_train indexes: Index([15434806, 15434821, 15434836, 15434851, 15434866, 15434881, 15434896,
#        15434911, 15434926, 15434941,
#        ...
#        15555509, 15555519, 15555535, 15555550, 15555560, 15555575, 15555592,
#        15555607, 15555637, 15555655],
#       dtype='int64', length=24374)
# (52017, 217)
# Step PrepareXYStep completed in 0.08 seconds
# Executing step: TrainModelStep
# Validation set size: 3374
# X_eval first 5 rows:
#           product_id  customer_id  cust_request_qty  cust_request_tn   tn  \
# 15434814       21244        10001                 0              0.0  0.0
# 15434829       21244        10002                 0              0.0  0.0
# 15434844       21244        10003                 0              0.0  0.0
# 15434859       21244        10004                 0              0.0  0.0
# 15434874       21244        10005                 0              0.0  0.0
#
#           stock_final cat1     cat2     cat3  brand  ...  \
# 15434814          NaN   PC  CABELLO  SHAMPOO  VICHY  ...
# 15434829          NaN   PC  CABELLO  SHAMPOO  VICHY  ...
# 15434844          NaN   PC  CABELLO  SHAMPOO  VICHY  ...
# 15434859          NaN   PC  CABELLO  SHAMPOO  VICHY  ...
# 15434874          NaN   PC  CABELLO  SHAMPOO  VICHY  ...
#
#           tn_div_tn_cat1_vendidas  tn_div_tn_cat2_vendidas  \
# 15434814                      0.0                      0.0
# 15434829                      0.0                      0.0
# 15434844                      0.0                      0.0
# 15434859                      0.0                      0.0
# 15434874                      0.0                      0.0
#
#           tn_div_tn_cat3_vendidas  tn_div_tn_brand_vendidas  \
# 15434814                      0.0                       0.0
# 15434829                      0.0                       0.0
# 15434844                      0.0                       0.0
# 15434859                      0.0                       0.0
# 15434874                      0.0                       0.0
#
#           tn_prod_cust_request_qty  tn_customer_vendidas  tn_total_vendidas  \
# 15434814                       0.0                   0.0           0.088867
# 15434829                       0.0                   0.0           0.088867
# 15434844                       0.0                   0.0           0.088867
# 15434859                       0.0                   0.0           0.088867
# 15434874                       0.0                   0.0           0.088867
#
#           customer_weight  tn_product_vendidas  product_weight
# 15434814              0.0             0.009872        0.111084
# 15434829              0.0             0.009872        0.111084
# 15434844              0.0             0.009872        0.111084
# 15434859              0.0             0.009872        0.111084
# 15434874              0.0             0.009872        0.111084
#
# [5 rows x 215 columns]
# y_eval first 5 rows:
#           target
# 15434814     0.0
# 15434829     0.0
# 15434844     0.0
# 15434859     0.0
# 15434874     0.0
# /home/fede/.venvs/labo3/lib/python3.12/site-packages/pandas/io/formats/format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
# /home/fede/.venvs/labo3/lib/python3.12/site-packages/pandas/io/formats/format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
# [100]	valid_0's l2: 1.30734e-06	valid_0's total_error: 0.911761
# [200]	valid_0's l2: 9.73071e-07	valid_0's total_error: 0.632028
# [300]	valid_0's l2: 1.11821e-06	valid_0's total_error: 0.501755
# [400]	valid_0's l2: 1.25656e-06	valid_0's total_error: 0.451271
# [500]	valid_0's l2: 1.46132e-06	valid_0's total_error: 0.435465
# [600]	valid_0's l2: 1.71978e-06	valid_0's total_error: 0.438427
# [700]	valid_0's l2: 1.78077e-06	valid_0's total_error: 0.431299
# [800]	valid_0's l2: 1.88346e-06	valid_0's total_error: 0.434133
# [900]	valid_0's l2: 2.05382e-06	valid_0's total_error: 0.443544
# [1000]	valid_0's l2: 2.00365e-06	valid_0's total_error: 0.430082
# [1100]	valid_0's l2: 2.03885e-06	valid_0's total_error: 0.41818
# [1200]	valid_0's l2: 2.12902e-06	valid_0's total_error: 0.425334
# [1300]	valid_0's l2: 2.18616e-06	valid_0's total_error: 0.425328
# [1400]	valid_0's l2: 2.19284e-06	valid_0's total_error: 0.423521
# [1500]	valid_0's l2: 2.23506e-06	valid_0's total_error: 0.425121
# Step TrainModelStep completed in 23.05 seconds
# Executing step: PredictStep
# Step PredictStep completed in 0.43 seconds
# Executing step: InverseResidualTargetStep
# Step InverseResidualTargetStep completed in 0.66 seconds
# Executing step: InverseScalePredictionsStep
# Step InverseScalePredictionsStep completed in 0.01 seconds
# Executing step: IntegratePredictionsStep
# Step IntegratePredictionsStep completed in 0.01 seconds
# Executing step: EvaluatePredictionsSteps
# Error en test: 1.4266
#
# Top 5 productos con mayor error absoluto:
#    product_id    target  predictions   tn_real   tn_pred  error_absoluto
# 6       21263  0.033850    -0.016472  0.033850 -0.016472        0.050322
# 0       21244  0.038074    -0.009510  0.038074 -0.009510        0.047584
# 4       21259  0.031038    -0.013992  0.031038 -0.013992        0.045030
# 3       21256  0.029625    -0.014238  0.029625 -0.014238        0.043863
# 1       21246  0.023964    -0.011683  0.023964 -0.011683        0.035647
# Step EvaluatePredictionsSteps completed in 0.02 seconds
# Executing step: EvaluatePredictionsOptimizatedSteps
# alfa optimizado: 0.0000
# Error en train: 1.0000
# Error en test: 1.0003
#
# Top 5 productos con mayor error absoluto en train:
#    product_id    target  predictions   tn_real  tn_pred  error_absoluto
# 4       21259  0.031046          0.0  0.031046      0.0        0.031046
# 6       21263  0.029643          0.0  0.029643      0.0        0.029643
# 3       21256  0.028229          0.0  0.028229      0.0        0.028229
# 0       21244  0.018327          0.0  0.018327      0.0        0.018327
# 2       21248  0.016922          0.0  0.016922      0.0        0.016922
#
# Top 5 productos con mayor error absoluto en test:
#    product_id    target  predictions   tn_real  tn_pred  error_absoluto
# 0       21244  0.019748          0.0  0.019748      0.0        0.019748
# 5       21262  0.014118          0.0  0.014118      0.0        0.014118
# 1       21246  0.007046          0.0  0.007046      0.0        0.007046
# 2       21248  0.004228          0.0  0.004228      0.0        0.004228
# 6       21263  0.004207          0.0  0.004207      0.0        0.004207
# Step EvaluatePredictionsOptimizatedSteps completed in 0.04 seconds
# /tmp/ipykernel_98974/3669324445.py:148: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['base_prediction'] = (

# %%
pipeline_results
# Out:
# {'ARIEL': {'eval_df':     product_id       target  predictions      tn_real      tn_pred  \
#   0        20001  1261.322642  1515.850805  1261.322642  1515.850805
#   1        20045   115.114431   183.234329   115.114431   183.234329
#   2        20102    35.854906    49.655575    35.854906    49.655575
#   3        20135   106.473853   108.751898   106.473853   108.751898
#   4        20150    68.611140    88.441539    68.611140    88.441539
#   5        20378    27.132943    24.909370    27.132943    24.909370
#   6        20611    10.865433    16.318514    10.865433    16.318514
#   7        20649    11.354645    75.591061    11.354645    75.591061
#   8        20682     5.673025    14.260145     5.673025    14.260145
#   9        20691    23.896790    56.474383    23.896790    56.474383
#   10       20919     0.970280     4.297042     0.970280     4.297042
#
#       error_absoluto
#   0       254.528162
#   1        68.119897
#   2        13.800669
#   3         2.278045
#   4        19.830400
#   5         2.223573
#   6         5.453081
#   7        64.236416
#   8         8.587120
#   9        32.577593
#   10        3.326763  ,
#   'alpha_opt': np.float64(0.8420790165120463)},
#  'LIMPIEX': {'eval_df':     product_id      target  predictions     tn_real      tn_pred  \
#   0        20002  813.761120  1152.078789  813.761120  1152.078789
#   1        20006  262.751018   481.257253  262.751018   481.257253
#   2        20008  233.032150   476.626856  233.032150   476.626856
#   3        20010  199.851811   405.018733  199.851811   405.018733
#   4        20011  287.883263   301.241115  287.883263   301.241115
#   5        20016  184.257540   313.364455  184.257540   313.364455
#   6        20017  165.137834   287.540387  165.137834   287.540387
#   7        20018  127.573596   299.496817  127.573596   299.496817
#   8        20020  235.548999   216.648318  235.548999   216.648318
#   9        20021  187.665690   265.015412  187.665690   265.015412
#   10       20022  242.367024   193.344810  242.367024   193.344810
#   11       20024  193.151835   206.647968  193.151835   206.647968
#   12       20025  200.375856   216.136389  200.375856   216.136389
#   13       20026  119.362392   264.828624  119.362392   264.828624
#   14       20029   91.507539   193.873028   91.507539   193.873028
#   15       20030  113.991300   146.854868  113.991300   146.854868
#   16       20031  127.387482   189.816085  127.387482   189.816085
#   17       20035  122.066877   171.497069  122.066877   171.497069
#   18       20039  118.131032   133.792317  118.131032   133.792317
#   19       20041  112.526861   157.762676  112.526861   157.762676
#   20       20043   79.384077   155.456285   79.384077   155.456285
#   21       20050  109.830172   131.703788  109.830172   131.703788
#   22       20082   95.290123    71.524249   95.290123    71.524249
#   23       20085  170.380332   146.100704  170.380332   146.100704
#   24       20097   53.210007    69.769758   53.210007    69.769758
#   25       20099   37.748231    80.567568   37.748231    80.567568
#   26       20109   42.657248    65.550664   42.657248    65.550664
#   27       20126   47.368020    91.947989   47.368020    91.947989
#   28       20148   72.661317    60.158487   72.661317    60.158487
#   29       20162   53.097047    26.551530   53.097047    26.551530
#   30       20164   55.949244    52.323213   55.949244    52.323213
#   31       20168   14.461707    34.189751   14.461707    34.189751
#   32       20174  120.935993    72.950520  120.935993    72.950520
#   33       20180   29.583057    35.669207   29.583057    35.669207
#   34       20222    5.876528    26.217310    5.876528    26.217310
#   35       20233   28.159321    29.712704   28.159321    29.712704
#   36       20280   15.785199    16.827803   15.785199    16.827803
#   37       20286   45.733449    47.326492   45.733449    47.326492
#   38       20288   12.615386    14.849093   12.615386    14.849093
#   39       20332   12.816009    17.709340   12.816009    17.709340
#   40       20361    7.786783    14.298230    7.786783    14.298230
#   41       20442   25.436733    39.381375   25.436733    39.381375
#   42       20548    9.701627    25.493428    9.701627    25.493428
#   43       20576    2.882767     4.819668    2.882767     4.819668
#   44       20620   13.519560    24.388319   13.519560    24.388319
#
#       error_absoluto
#   0       338.317669
#   1       218.506236
#   2       243.594707
#   3       205.166922
#   4        13.357852
#   5       129.106915
#   6       122.402552
#   7       171.923221
#   8        18.900681
#   9        77.349721
#   10       49.022214
#   11       13.496133
#   12       15.760533
#   13      145.466232
#   14      102.365489
#   15       32.863567
#   16       62.428603
#   17       49.430192
#   18       15.661285
#   19       45.235816
#   20       76.072208
#   21       21.873616
#   22       23.765875
#   23       24.279628
#   24       16.559750
#   25       42.819338
#   26       22.893416
#   27       44.579970
#   28       12.502830
#   29       26.545517
#   30        3.626031
#   31       19.728044
#   32       47.985473
#   33        6.086150
#   34       20.340782
#   35        1.553383
#   36        1.042603
#   37        1.593043
#   38        2.233707
#   39        4.893331
#   40        6.511446
#   41       13.944642
#   42       15.791801
#   43        1.936900
#   44       10.868759  ,
#   'alpha_opt': np.float64(0.7463205226171964)},
#  'NATURA': {'eval_df':     product_id      target  predictions     tn_real     tn_pred  \
#   0        20003  635.607411   700.496438  635.607411  700.496438
#   1        20004  482.038922   593.594712  482.038922  593.594712
#   2        20005  536.416067   565.883949  536.416067  565.883949
#   3        20019  231.815264   306.862243  231.815264  306.862243
#   4        20033  224.326797   178.948073  224.326797  178.948073
#   5        20046  155.452297   124.535734  155.452297  124.535734
#   6        20095  110.924558    95.223814  110.924558   95.223814
#   7        20108   60.506898    66.837088   60.506898   66.837088
#   8        20118   57.591234    53.782285   57.591234   53.782285
#   9        20119  165.810220    74.266432  165.810220   74.266432
#   10       20146   42.795415    52.079287   42.795415   52.079287
#   11       20207   24.251597    26.817461   24.251597   26.817461
#   12       20242   21.263572    17.231099   21.263572   17.231099
#   13       20264   17.590861    16.601058   17.590861   16.601058
#   14       20266   35.755159    27.108680   35.755159   27.108680
#   15       20289   17.471165    15.967201   17.471165   15.967201
#   16       20322    7.011677    13.120432    7.011677   13.120432
#   17       20325    6.884483     8.838994    6.884483    8.838994
#   18       20379    6.815225    10.155109    6.815225   10.155109
#   19       20384   13.472445    10.774621   13.472445   10.774621
#   20       20396   10.536498     8.360582   10.536498    8.360582
#   21       20459   17.895337    17.068805   17.895337   17.068805
#   22       20503   15.453478    14.389538   15.453478   14.389538
#   23       20522   10.725619    13.092658   10.725619   13.092658
#   24       20547   10.707789    12.237011   10.707789   12.237011
#   25       20580   14.889183    10.780901   14.889183   10.780901
#   26       20609    3.480194     2.463097    3.480194    2.463097
#
#       error_absoluto
#   0        64.889026
#   1       111.555790
#   2        29.467882
#   3        75.046979
#   4        45.378723
#   5        30.916562
#   6        15.700744
#   7         6.330190
#   8         3.808948
#   9        91.543789
#   10        9.283872
#   11        2.565865
#   12        4.032473
#   13        0.989803
#   14        8.646479
#   15        1.503963
#   16        6.108755
#   17        1.954511
#   18        3.339884
#   19        2.697824
#   20        2.175916
#   21        0.826532
#   22        1.063940
#   23        2.367039
#   24        1.529222
#   25        4.108282
#   26        1.017097  ,
#   'alpha_opt': np.float64(0.9310291140546157)},
#  'DOWNY': {'eval_df':     product_id      target  predictions     tn_real     tn_pred  \
#   0        20007  307.829776   448.582901  307.829776  448.582901
#   1        20012  301.510898   354.465607  301.510898  354.465607
#   2        20014  262.116031   430.725765  262.116031  430.725765
#   3        20049  211.369621   228.468219  211.369621  228.468219
#   4        20051  128.834699   156.433212  128.834699  156.433212
#   5        20074   85.021427    91.743739   85.021427   91.743739
#   6        20087   70.981250    74.135345   70.981250   74.135345
#   7        20218   27.966153    29.203715   27.966153   29.203715
#   8        20358   12.688770     9.664921   12.688770    9.664921
#   9        20426    6.299391     3.986058    6.299391    3.986058
#   10       20520    8.080151     5.816759    8.080151    5.816759
#   11       20530    3.992903     6.349315    3.992903    6.349315
#   12       20733    4.683199     1.457356    4.683199    1.457356
#
#       error_absoluto
#   0       140.753124
#   1        52.954709
#   2       168.609734
#   3        17.098598
#   4        27.598513
#   5         6.722313
#   6         3.154095
#   7         1.237562
#   8         3.023849
#   9         2.313333
#   10        2.263393
#   11        2.356413
#   12        3.225843  ,
#   'alpha_opt': np.float64(0.6601159167170029)},
#  'ROPEX1': {'eval_df':     product_id      target  predictions     tn_real     tn_pred  \
#   0        20009  520.370284   561.896647  520.370284  561.896647
#   1        20015  277.524176   426.091565  277.524176  426.091565
#   2        20028   61.665009   237.904734   61.665009  237.904734
#   3        20038  116.561168   199.230429  116.561168  199.230429
#   4        20066   74.357643   132.250097   74.357643  132.250097
#   5        20067   72.853989   116.008812   72.853989  116.008812
#   6        20069   66.775170   135.744099   66.775170  135.744099
#   7        20071   53.545999   144.285547   53.545999  144.285547
#   8        20072   70.826817   126.163865   70.826817  126.163865
#   9        20091   71.299904   115.617843   71.299904  115.617843
#   10       20151   31.547161    62.703810   31.547161   62.703810
#   11       20203    6.960813    52.751678    6.960813   52.751678
#   12       20262   18.147307    30.627559   18.147307   30.627559
#
#       error_absoluto
#   0        41.526363
#   1       148.567388
#   2       176.239725
#   3        82.669261
#   4        57.892454
#   5        43.154823
#   6        68.968929
#   7        90.739548
#   8        55.337048
#   9        44.317939
#   10       31.156649
#   11       45.790865
#   12       12.480251  ,
#   'alpha_opt': np.float64(0.5493183232306443)},
#  'MUSCULO': {'eval_df':     product_id      target  predictions     tn_real     tn_pred  \
#   0        20013  191.958297   383.506547  191.958297  383.506547
#   1        20027  217.253462   233.408599  217.253462  233.408599
#   2        20042  119.015616   157.020070  119.015616  157.020070
#   3        20053  101.155097   146.469255  101.155097  146.469255
#   4        20057   76.759070   144.860580   76.759070  144.860580
#   ..         ...         ...          ...         ...         ...
#   57       21155    0.252644     0.348923    0.252644    0.348923
#   58       21167    0.114268     0.527429    0.114268    0.527429
#   59       21180    0.049034     0.543681    0.049034    0.543681
#   60       21184    0.288709     0.479803    0.288709    0.479803
#   61       21212    0.177695     0.537766    0.177695    0.537766
#
#       error_absoluto
#   0       191.548250
#   1        16.155137
#   2        38.004455
#   3        45.314158
#   4        68.101510
#   ..             ...
#   57        0.096279
#   58        0.413161
#   59        0.494648
#   60        0.191094
#   61        0.360071
#
#   [62 rows x 6 columns],
#   'alpha_opt': np.float64(0.6713614219478069)},
#  'MOSTAZA1': {'eval_df':    product_id      target  predictions     tn_real     tn_pred  error_absoluto
#   0       20023  262.634825   257.876754  262.634825  257.876754        4.758072
#   1       20100  122.506865   107.571330  122.506865  107.571330       14.935535
#   2       20211   23.234500    29.048703   23.234500   29.048703        5.814203
#   3       20375   11.554384    12.456332   11.554384   12.456332        0.901948
#   4       20684    2.354284     4.227180    2.354284    4.227180        1.872896,
#   'alpha_opt': np.float64(0.807132677475068)},
#  'ROPEX2': {'eval_df':    product_id      target  predictions     tn_real     tn_pred  error_absoluto
#   0       20032  703.110658   448.252520  703.110658  448.252520      254.858138
#   1       20089  287.991140   184.650549  287.991140  184.650549      103.340591,
#   'alpha_opt': np.float64(1.5239678081459043)},
#  'MAGGI': {'eval_df':     product_id      target  predictions     tn_real     tn_pred  \
#   0        20037  101.306992   150.935746  101.306992  150.935746
#   1        20052  110.355256   106.335124  110.355256  106.335124
#   2        20077   64.078992   102.063124   64.078992  102.063124
#   3        20079   41.167674    79.137845   41.167674   79.137845
#   4        20090   42.831797    76.738673   42.831797   76.738673
#   ..         ...         ...          ...         ...         ...
#   73       21064    1.460853     3.404654    1.460853    3.404654
#   74       21088    0.356537    -0.070401    0.356537   -0.070401
#   75       21099    0.838699     3.160097    0.838699    3.160097
#   76       21131    0.278335    -0.301603    0.278335   -0.301603
#   77       21182    0.140454    -0.361644    0.140454   -0.361644
#
#       error_absoluto
#   0        49.628753
#   1         4.020132
#   2        37.984132
#   3        37.970171
#   4        33.906876
#   ..             ...
#   73        1.943801
#   74        0.426938
#   75        2.321398
#   76        0.579938
#   77        0.502098
#
#   [78 rows x 6 columns],
#   'alpha_opt': np.float64(0.764798131361663)},
#  'SHAMPOO2': {'eval_df':     product_id      target  predictions     tn_real     tn_pred  \
#   0        20044   67.952581   179.394719   67.952581  179.394719
#   1        20047  113.462266   172.625634  113.462266  172.625634
#   2        20054   70.357692   134.914240   70.357692  134.914240
#   3        20059  103.888048   133.731111  103.888048  133.731111
#   4        20061   93.563973   135.217025   93.563973  135.217025
#   5        20075   84.786514   126.073189   84.786514  126.073189
#   6        20080   62.748270    95.391656   62.748270   95.391656
#   7        20094   69.608544   100.048149   69.608544  100.048149
#   8        20130   51.066470   107.666449   51.066470  107.666449
#   9        20143   31.294566   114.097708   31.294566  114.097708
#   10       20159   50.257678    86.554318   50.257678   86.554318
#   11       20170   46.263660    81.564548   46.263660   81.564548
#   12       20355   41.113581    36.206950   41.113581   36.206950
#   13       20414   31.565239    30.799901   31.565239   30.799901
#   14       20458   22.846974    29.533277   22.846974   29.533277
#   15       20464    5.533568    15.297035    5.533568   15.297035
#   16       20465    4.999618    14.449499    4.999618   14.449499
#   17       20476   20.130152    29.790306   20.130152   29.790306
#   18       20497    4.777566    13.081501    4.777566   13.081501
#   19       20502    4.310957    11.906380    4.310957   11.906380
#   20       20521   15.672215    30.853975   15.672215   30.853975
#   21       20526   14.062595    29.359863   14.062595   29.359863
#   22       20531   18.953800    24.401757   18.953800   24.401757
#   23       20551    3.610333    11.241070    3.610333   11.241070
#   24       20927    4.384377    17.148514    4.384377   17.148514
#   25       20945    0.016195     5.657197    0.016195    5.657197
#   26       20951    0.008548     5.647442    0.008548    5.647442
#
#       error_absoluto
#   0       111.442138
#   1        59.163367
#   2        64.556548
#   3        29.843063
#   4        41.653052
#   5        41.286674
#   6        32.643386
#   7        30.439605
#   8        56.599980
#   9        82.803143
#   10       36.296641
#   11       35.300889
#   12        4.906631
#   13        0.765338
#   14        6.686303
#   15        9.763467
#   16        9.449881
#   17        9.660154
#   18        8.303935
#   19        7.595424
#   20       15.181760
#   21       15.297268
#   22        5.447957
#   23        7.630738
#   24       12.764138
#   25        5.641002
#   26        5.638894  ,
#   'alpha_opt': np.float64(0.6082164341704926)},
#  'VIVERE': {'eval_df':    product_id      target  predictions     tn_real    tn_pred  error_absoluto
#   0       20055  113.078862    94.109993  113.078862  94.109993       18.968869
#   1       20056  116.210440    85.905031  116.210440  85.905031       30.305409
#   2       20304    4.543392    11.302317    4.543392  11.302317        6.758924
#   3       20473   14.563774     5.783428   14.563774   5.783428        8.780346
#   4       20513    4.179424     6.217364    4.179424   6.217364        2.037940
#   5       20588    5.863267     3.836235    5.863267   3.836235        2.027032
#   6       20666    1.397758     2.716935    1.397758   2.716935        1.319176
#   7       20705    3.734336     2.171977    3.734336   2.171977        1.562359
#   8       20724    0.216113     2.256452    0.216113   2.256452        2.040339
#   9       20737    2.199914     2.002492    2.199914   2.002492        0.197422,
#   'alpha_opt': np.float64(1.4423120012425283)},
#  'NIVEA': {'eval_df':     product_id      target  predictions     tn_real     tn_pred  \
#   0        20058  128.549485   101.906535  128.549485  101.906535
#   1        20122   52.858464    68.304929   52.858464   68.304929
#   2        20189   27.528275    36.919336   27.528275   36.919336
#   3        20212   26.113513    25.946964   26.113513   25.946964
#   4        20244   16.436290    19.017224   16.436290   19.017224
#   ..         ...         ...          ...         ...         ...
#   85       21168    0.355976     0.768142    0.355976    0.768142
#   86       21171    0.292648     1.299315    0.292648    1.299315
#   87       21252    0.134452     0.495230    0.134452    0.495230
#   88       21267    0.040538     0.358230    0.040538    0.358230
#   89       21276    0.012640     0.286288    0.012640    0.286288
#
#       error_absoluto
#   0        26.642951
#   1        15.446466
#   2         9.391060
#   3         0.166548
#   4         2.580934
#   ..             ...
#   85        0.412166
#   86        1.006667
#   87        0.360778
#   88        0.317691
#   89        0.273648
#
#   [90 rows x 6 columns],
#   'alpha_opt': np.float64(0.8263939038451181)},
#  'AYUDIN': {'eval_df':     product_id     target  predictions    tn_real    tn_pred  error_absoluto
#   0        20062  79.208416    92.263418  79.208416  92.263418       13.055002
#   1        20117  37.192701    42.877253  37.192701  42.877253        5.684552
#   2        20138  19.238169    41.570625  19.238169  41.570625       22.332456
#   3        20239  15.674547    18.176650  15.674547  18.176650        2.502103
#   4        20421  11.768684     9.988771  11.768684   9.988771        1.779913
#   5        20491   9.630635    14.315953   9.630635  14.315953        4.685319
#   6        20750   3.195003     3.792292   3.195003   3.792292        0.597289
#   7        20757   2.978947     7.248350   2.978947   7.248350        4.269404
#   8        20855   2.206209     2.407137   2.206209   2.407137        0.200928
#   9        20877   1.063241     2.008220   1.063241   2.008220        0.944980
#   10       20996   0.821653     1.060051   0.821653   1.060051        0.238397
#   11       21003   0.847375     1.059374   0.847375   1.059374        0.212000
#   12       21033   1.296587     2.114807   1.296587   2.114807        0.818220
#   13       21042   1.434178     2.304146   1.434178   2.304146        0.869967
#   14       21044   1.408272     2.038831   1.408272   2.038831        0.630559
#   15       21073   0.717020     1.802202   0.717020   1.802202        1.085182,
#   'alpha_opt': np.float64(0.8545651734623156)},
#  'DEOS1': {'eval_df':     product_id     target  predictions    tn_real    tn_pred  error_absoluto
#   0        20081  66.781934    84.283399  66.781934  84.283399       17.501466
#   1        20093  92.466850    77.515066  92.466850  77.515066       14.951785
#   2        20101  80.328898    70.302149  80.328898  70.302149       10.026749
#   3        20106  61.770143    65.734835  61.770143  65.734835        3.964692
#   4        20111  51.954616    74.748391  51.954616  74.748391       22.793774
#   ..         ...        ...          ...        ...        ...             ...
#   67       21014   1.047800     1.027498   1.047800   1.027498        0.020301
#   68       21037   0.654040     1.097559   0.654040   1.097559        0.443519
#   69       21065   0.324889     0.820774   0.324889   0.820774        0.495885
#   70       21092   0.430595     1.208472   0.430595   1.208472        0.777877
#   71       21179   0.273243     0.787376   0.273243   0.787376        0.514134
#
#   [72 rows x 6 columns],
#   'alpha_opt': np.float64(0.9280487751497474)},
#  'MAYOS3': {'eval_df':    product_id      target  predictions     tn_real     tn_pred  error_absoluto
#   0       20084  134.675781   123.725320  134.675781  123.725320       10.950461
#   1       20116  129.168281    92.936235  129.168281   92.936235       36.232046
#   2       20121   85.494802    82.433158   85.494802   82.433158        3.061644
#   3       20158   74.011340    59.640278   74.011340   59.640278       14.371062
#   4       20224   31.222384    33.062649   31.222384   33.062649        1.840265
#   5       20227   51.964355    38.164210   51.964355   38.164210       13.800145
#   6       20232   54.565499    31.589796   54.565499   31.589796       22.975703,
#   'alpha_opt': np.float64(0.9957725181250917)},
#  'HARINAMA': {'eval_df':    product_id     target  predictions    tn_real    tn_pred  error_absoluto
#   0       20086  45.602805    79.012338  45.602805  79.012338       33.409534
#   1       20096  51.768200    81.513957  51.768200  81.513957       29.745757
#   2       20558  10.992732    16.801206  10.992732  16.801206        5.808474
#   3       20689   6.166529    10.962184   6.166529  10.962184        4.795655
#   4       20817   4.754316     8.563429   4.754316   8.563429        3.809113
#   5       20835   4.630319     7.998744   4.630319   7.998744        3.368426,
#   'alpha_opt': np.float64(0.5531942072865617)},
#  'MAJESTA': {'eval_df':    product_id     target  predictions    tn_real    tn_pred  error_absoluto
#   0       20107  90.783370    79.555848  90.783370  79.555848       11.227522
#   1       20161  57.782578    53.222361  57.782578  53.222361        4.560216
#   2       20175  22.958350    46.067781  22.958350  46.067781       23.109431
#   3       20270  14.757801    23.590270  14.757801  23.590270        8.832469
#   4       20299  42.858681    23.067616  42.858681  23.067616       19.791065
#   5       20328  19.481895    22.207126  19.481895  22.207126        2.725231,
#   'alpha_opt': np.float64(1.2332728705175884)},
#  'MAGGI2': {'eval_df':    product_id     target  predictions    tn_real    tn_pred  error_absoluto
#   0       20142  49.201926    77.764030  49.201926  77.764030       28.562103
#   1       20240  18.321323    33.625657  18.321323  33.625657       15.304334
#   2       20259  12.400438    27.937460  12.400438  27.937460       15.537022
#   3       20285  14.882624    25.795932  14.882624  25.795932       10.913307
#   4       20565   4.947940    10.927624   4.947940  10.927624        5.979685,
#   'alpha_opt': np.float64(0.45306720531439404)},
#  'SHAMPOO3': {'eval_df':     product_id     target  predictions    tn_real    tn_pred  error_absoluto
#   0        20145  38.803561    36.534948  38.803561  36.534948        2.268614
#   1        20153  46.489536    40.120433  46.489536  40.120433        6.369103
#   2        20155  43.187673    35.452058  43.187673  35.452058        7.735615
#   3        20157  45.399356    38.744447  45.399356  38.744447        6.654909
#   4        20167  37.681482    30.770380  37.681482  30.770380        6.911101
#   ..         ...        ...          ...        ...        ...             ...
#   77       20822   4.956163     7.683406   4.956163   7.683406        2.727243
#   78       21007   1.896563     2.921062   1.896563   2.921062        1.024500
#   79       21086   1.458538     3.867110   1.458538   3.867110        2.408572
#   80       21093   5.172138     1.330679   5.172138   1.330679        3.841459
#   81       21105   0.594478     1.507264   0.594478   1.507264        0.912786
#
#   [82 rows x 6 columns],
#   'alpha_opt': np.float64(0.8214208116425539)},
#  'SALSATI': {'eval_df':    product_id     target  predictions    tn_real    tn_pred  error_absoluto
#   0       20237  57.406896    52.453525  57.406896  52.453525        4.953371
#   1       20460  15.686462    18.611720  15.686462  18.611720        2.925258,
#   'alpha_opt': np.float64(1.318530153589752)},
#  'Importado': {'eval_df':    product_id     target  predictions    tn_real    tn_pred  error_absoluto
#   0       20196  43.290144    44.457801  43.290144  44.457801        1.167658
#   1       20311  22.873496    22.068220  22.873496  22.068220        0.805276
#   2       20388   8.047777    13.697450   8.047777  13.697450        5.649673
#   3       20524   7.305943     8.441138   7.305943   8.441138        1.135196
#   4       20652   5.552407     5.574878   5.552407   5.574878        0.022471,
#   'alpha_opt': np.float64(1.066191424184591)},
#  'GOMINA': {'eval_df':    product_id     target  predictions    tn_real    tn_pred  error_absoluto
#   0       20231  19.012537    21.396043  19.012537  21.396043        2.383506
#   1       20317  11.484347    12.238216  11.484347  12.238216        0.753869
#   2       20624   3.234848     4.104572   3.234848   4.104572        0.869723,
#   'alpha_opt': np.float64(0.7260761468563294)},
#  'JABON1': {'eval_df':    product_id    target  predictions   tn_real   tn_pred  error_absoluto
#   0       20928  5.391934     5.214101  5.391934  5.214101        0.177833
#   1       21022  1.133048     0.913102  1.133048  0.913102        0.219946
#   2       21056  1.356857     1.286173  1.356857  1.286173        0.070684,
#   'alpha_opt': np.float64(0.7803692179841002)},
#  'COLBERT': {'eval_df':     product_id     target  predictions    tn_real    tn_pred  error_absoluto
#   0        20263  11.042422    19.156691  11.042422  19.156691        8.114269
#   1        20267  12.365496    17.604494  12.365496  17.604494        5.238998
#   2        20321  18.421051    10.924209  18.421051  10.924209        7.496842
#   3        20367  11.592561    10.478996  11.592561  10.478996        1.113565
#   4        20386   9.272505    10.903351   9.272505  10.903351        1.630846
#   5        20481   6.040918     8.705036   6.040918   8.705036        2.664118
#   6        20496   5.975419     7.745678   5.975419   7.745678        1.770259
#   7        20536   4.277947     5.750214   4.277947   5.750214        1.472267
#   8        20539   2.979471     5.239374   2.979471   5.239374        2.259903
#   9        20599   2.269278     4.598238   2.269278   4.598238        2.328960
#   10       20719   7.626174     6.844760   7.626174   6.844760        0.781414
#   11       20811   1.814049     3.448023   1.814049   3.448023        1.633974
#   12       20818   1.040953     1.808068   1.040953   1.808068        0.767116
#   13       20920   3.033718     3.161922   3.033718   3.161922        0.128204
#   14       21027   0.875719     0.761914   0.875719   0.761914        0.113805
#   15       21034   1.319701     0.899170   1.319701   0.899170        0.420531
#   16       21040   0.441798     0.748134   0.441798   0.748134        0.306337
#   17       21164   0.577769     0.349233   0.577769   0.349233        0.228535
#   18       21176   0.249410     0.315201   0.249410   0.315201        0.065791
#   19       21196   0.475612     0.561641   0.475612   0.561641        0.086029
#   20       21227   0.619578     2.468599   0.619578   2.468599        1.849021,
#   'alpha_opt': np.float64(0.7621648203243522)},
#  'SHAMPOO1': {'eval_df':     product_id     target  predictions    tn_real    tn_pred  error_absoluto
#   0        20346  12.900051    11.907372  12.900051  11.907372        0.992679
#   1        20352  19.210268    11.554743  19.210268  11.554743        7.655526
#   2        20372   9.912680    11.280955   9.912680  11.280955        1.368275
#   3        20380  15.992130     9.419215  15.992130   9.419215        6.572915
#   4        20381  15.162040     9.320012  15.162040   9.320012        5.842028
#   5        20404   5.656020    10.600095   5.656020  10.600095        4.944075
#   6        20433  11.821549     7.004063  11.821549   7.004063        4.817486
#   7        20438  14.224800     7.673587  14.224800   7.673587        6.551213
#   8        20443   6.429350     8.644113   6.429350   8.644113        2.214763
#   9        20456   8.910009     7.116172   8.910009   7.116172        1.793837
#   10       20466   5.943130     8.007222   5.943130   8.007222        2.064092
#   11       20474   8.630423     5.741137   8.630423   5.741137        2.889286
#   12       20480   6.292967     6.617202   6.292967   6.617202        0.324235
#   13       20514   7.231396     5.668921   7.231396   5.668921        1.562475
#   14       20532   3.547818     6.381976   3.547818   6.381976        2.834159
#   15       20544   7.479260     6.251267   7.479260   6.251267        1.227993
#   16       20572   4.133051     4.657422   4.133051   4.657422        0.524371
#   17       20578   4.255504     4.625528   4.255504   4.625528        0.370024
#   18       20589   5.119699     4.801025   5.119699   4.801025        0.318674
#   19       20602   4.452506     4.120364   4.452506   4.120364        0.332142
#   20       20629   2.560584     3.703456   2.560584   3.703456        1.142871
#   21       20632   3.667594     3.983766   3.667594   3.983766        0.316172
#   22       20677   2.538229     3.138508   2.538229   3.138508        0.600278
#   23       20743   2.267105     3.163353   2.267105   3.163353        0.896248
#   24       20771   1.573995     2.274646   1.573995   2.274646        0.700651
#   25       20931   0.838636     1.004202   0.838636   1.004202        0.165566
#   26       21077   0.089405     0.377043   0.089405   0.377043        0.287638,
#   'alpha_opt': np.float64(0.940221003526302)},
#  'DEOS3': {'eval_df':    product_id    target  predictions   tn_real   tn_pred  error_absoluto
#   0       20424  6.704089     9.529806  6.704089  9.529806        2.825717
#   1       20432  5.829678     7.965596  5.829678  7.965596        2.135918
#   2       20484  4.573177     7.228927  4.573177  7.228927        2.655749
#   3       20505  5.395396     7.507859  5.395396  7.507859        2.112463
#   4       20667  2.550402     7.401281  2.550402  7.401281        4.850878
#   5       21190  0.077765     0.224763  0.077765  0.224763        0.146998
#   6       21200  0.066058     0.190087  0.066058  0.190087        0.124029
#   7       21224  0.050213     0.338907  0.050213  0.338907        0.288694,
#   'alpha_opt': np.float64(0.6099881965534023)},
#  'LANCOME': {'eval_df':     product_id    target  predictions   tn_real   tn_pred  error_absoluto
#   0        20463  8.720305     7.660262  8.720305  7.660262        1.060044
#   1        20538  3.949441     5.612597  3.949441  5.612597        1.663156
#   2        20549  2.796434     4.654667  2.796434  4.654667        1.858234
#   3        20570  4.303209     5.065222  4.303209  5.065222        0.762013
#   4        20661  3.019747     3.320608  3.019747  3.320608        0.300860
#   5        20693  1.807688     3.063042  1.807688  3.063042        1.255354
#   6        20708  2.084407     2.379625  2.084407  2.379625        0.295218
#   7        20714  1.502158     2.915160  1.502158  2.915160        1.413002
#   8        20786  1.456840     1.779174  1.456840  1.779174        0.322333
#   9        20801  1.867212     1.834668  1.867212  1.834668        0.032543
#   10       20862  1.675146     1.612860  1.675146  1.612860        0.062287
#   11       20865  1.244929     1.298389  1.244929  1.298389        0.053460
#   12       20882  1.194451     1.307570  1.194451  1.307570        0.113119
#   13       20885  1.277515     1.389875  1.277515  1.389875        0.112360
#   14       20922  0.345839     0.783857  0.345839  0.783857        0.438017
#   15       20937  0.925955     1.056098  0.925955  1.056098        0.130143
#   16       20957  0.751254     0.872959  0.751254  0.872959        0.121705
#   17       20976  0.809069     0.761439  0.809069  0.761439        0.047630
#   18       21028  0.783933     0.616181  0.783933  0.616181        0.167752
#   19       21055  0.316645     0.503229  0.316645  0.503229        0.186584
#   20       21057  0.426919     0.543830  0.426919  0.543830        0.116911
#   21       21074  1.030163     1.067988  1.030163  1.067988        0.037826
#   22       21080  0.420402     0.466562  0.420402  0.466562        0.046160
#   23       21135  0.407204     1.624595  0.407204  1.624595        1.217392
#   24       21140  0.615847     0.824614  0.615847  0.824614        0.208768
#   25       21157  0.195826     0.345251  0.195826  0.345251        0.149425
#   26       21163  0.222637     1.569384  0.222637  1.569384        1.346747
#   27       21265  0.015934     0.325517  0.015934  0.325517        0.309583
#   28       21266  0.014798     0.328205  0.014798  0.328205        0.313407,
#   'alpha_opt': np.float64(0.6938311985407396)},
#  'CAPILATIS': {'eval_df':    product_id    target  predictions   tn_real   tn_pred  error_absoluto
#   0       20470  7.275974     5.875838  7.275974  5.875838        1.400136
#   1       20482  8.016826     5.089852  8.016826  5.089852        2.926974
#   2       20560  3.509262     2.645421  3.509262  2.645421        0.863841
#   3       20579  4.953015     3.688483  4.953015  3.688483        1.264532
#   4       20596  4.733230     2.080801  4.733230  2.080801        2.652429
#   5       20606  3.156833     2.436571  3.156833  2.436571        0.720262
#   6       20713  2.992344     2.229427  2.992344  2.229427        0.762917
#   7       20745  2.375835     1.591995  2.375835  1.591995        0.783840
#   8       20824  0.773616     0.166656  0.773616  0.166656        0.606959,
#   'alpha_opt': np.float64(1.2931206772721022)},
#  'ESPADOL': {'eval_df':    product_id    target  predictions   tn_real   tn_pred  error_absoluto
#   0       20517  6.609933     4.991617  6.609933  4.991617        1.618315
#   1       20568  3.988671     3.612524  3.988671  3.612524        0.376146
#   2       20644  3.055013     2.651312  3.055013  2.651312        0.403701
#   3       20676  1.515272     2.403248  1.515272  2.403248        0.887976
#   4       20702  1.579659     2.423989  1.579659  2.423989        0.844330
#   5       20994  0.475008     0.719340  0.475008  0.719340        0.244332
#   6       21049  0.251943     0.607732  0.251943  0.607732        0.355789,
#   'alpha_opt': np.float64(1.0331903553065551)},
#  'COLGATE': {'eval_df':     product_id    target  predictions   tn_real   tn_pred  error_absoluto
#   0        20563  7.367811     6.905512  7.367811  6.905512        0.462299
#   1        20585  4.931136     5.323869  4.931136  5.323869        0.392733
#   2        20612  6.934809     5.559969  6.934809  5.559969        1.374841
#   3        20699  1.277931     3.629895  1.277931  3.629895        2.351964
#   4        20742  2.458861     1.696386  2.458861  1.696386        0.762476
#   5        20751  1.768794     1.537454  1.768794  1.537454        0.231341
#   6        20883  0.778526     1.022732  0.778526  1.022732        0.244206
#   7        20906  0.825724     0.960154  0.825724  0.960154        0.134431
#   8        20956  0.495423     0.633965  0.495423  0.633965        0.138542
#   9        20985  0.501334     0.623828  0.501334  0.623828        0.122494
#   10       21118  0.393557     0.348893  0.393557  0.348893        0.044665
#   11       21194  0.135891     0.162454  0.135891  0.162454        0.026563
#   12       21201  0.002991     0.528397  0.002991  0.528397        0.525406
#   13       21207  0.002933     0.483122  0.002933  0.483122        0.480189,
#   'alpha_opt': np.float64(0.86328057721916)},
#  'DEOS2': {'eval_df':    product_id    target  predictions   tn_real   tn_pred  error_absoluto
#   0       20583  4.225823     5.059568  4.225823  5.059568        0.833745
#   1       20654  2.935739     3.607938  2.935739  3.607938        0.672199
#   2       20838  0.955050     2.035248  0.955050  2.035248        1.080198
#   3       20840  0.709230     2.168350  0.709230  2.168350        1.459120
#   4       20849  1.134377     1.813997  1.134377  1.813997        0.679620
#   5       21111  1.202624     0.640724  1.202624  0.640724        0.561900
#   6       21114  1.122860     0.562119  1.122860  0.562119        0.560741
#   7       21119  1.089939     0.594835  1.089939  0.594835        0.495104,
#   'alpha_opt': np.float64(0.6665114556299465)},
#  'OFF': {'eval_df':    product_id    target  predictions   tn_real   tn_pred  error_absoluto
#   0       20657  0.053440     1.451028  0.053440  1.451028        1.397588
#   1       20741  0.059608     0.969204  0.059608  0.969204        0.909596,
#   'alpha_opt': np.float64(0.03846723958119409)},
#  'TWININGS': {'eval_df':    product_id    target  predictions   tn_real   tn_pred  error_absoluto
#   0       20982  0.886092     0.830246  0.886092  0.830246        0.055846
#   1       21170  0.159473     0.234643  0.159473  0.234643        0.075171
#   2       21192  0.028426     0.120138  0.028426  0.120138        0.091712
#   3       21202  0.085850     0.118720  0.085850  0.118720        0.032870
#   4       21218  0.045135     0.091504  0.045135  0.091504        0.046370
#   5       21222  0.044435     0.113234  0.044435  0.113234        0.068799,
#   'alpha_opt': np.float64(1.1798628063375)},
#  'SKIN1': {'eval_df':    product_id    target  predictions   tn_real   tn_pred  error_absoluto
#   0       21142  0.602781     0.512461  0.602781  0.512461        0.090320
#   1       21191  0.146995     0.215604  0.146995  0.215604        0.068609
#   2       21209  0.121953     0.164703  0.121953  0.164703        0.042750
#   3       21226  0.147976     0.213291  0.147976  0.213291        0.065315
#   4       21233  0.079804     0.158948  0.079804  0.158948        0.079144
#   5       21245  0.068272     0.223186  0.068272  0.223186        0.154914,
#   'alpha_opt': np.float64(0.8434227755395604)},
#  'VICHY': {'eval_df':    product_id    target  predictions   tn_real   tn_pred  error_absoluto
#   0       21244  0.038074    -0.009510  0.038074 -0.009510        0.047584
#   1       21246  0.023964    -0.011683  0.023964 -0.011683        0.035647
#   2       21248  0.021150    -0.006976  0.021150 -0.006976        0.028126
#   3       21256  0.029625    -0.014238  0.029625 -0.014238        0.043863
#   4       21259  0.031038    -0.013992  0.031038 -0.013992        0.045030
#   5       21262  0.022550    -0.012560  0.022550 -0.012560        0.035110
#   6       21263  0.033850    -0.016472  0.033850 -0.016472        0.050322,
#   'alpha_opt': np.float64(0.0)}}

# %%
final_eval_scaled = pd.DataFrame()
for brand, result in pipeline_results.items():
    alpha_opt = result["alpha_opt"]
    eval_df = result["eval_df"]
    eval_df["tn_pred_scaled"] = eval_df["tn_pred"] * alpha_opt
    final_eval_scaled = pd.concat([final_eval_scaled, eval_df], ignore_index=True)

# %%
final_eval_scaled
# Out:
#      product_id       target  predictions      tn_real      tn_pred  \
# 0         20001  1261.322642  1515.850805  1261.322642  1515.850805
# 1         20045   115.114431   183.234329   115.114431   183.234329
# 2         20102    35.854906    49.655575    35.854906    49.655575
# 3         20135   106.473853   108.751898   106.473853   108.751898
# 4         20150    68.611140    88.441539    68.611140    88.441539
# ..          ...          ...          ...          ...          ...
# 729       21248     0.021150    -0.006976     0.021150    -0.006976
# 730       21256     0.029625    -0.014238     0.029625    -0.014238
# 731       21259     0.031038    -0.013992     0.031038    -0.013992
# 732       21262     0.022550    -0.012560     0.022550    -0.012560
# 733       21263     0.033850    -0.016472     0.033850    -0.016472
#
#      error_absoluto  tn_pred_scaled
# 0        254.528162     1276.466155
# 1         68.119897      154.297783
# 2         13.800669       41.813918
# 3          2.278045       91.577691
# 4         19.830400       74.474764
# ..              ...             ...
# 729        0.028126       -0.000000
# 730        0.043863       -0.000000
# 731        0.045030       -0.000000
# 732        0.035110       -0.000000
# 733        0.050322       -0.000000
#
# [734 rows x 7 columns]

# %%
total_error_1 = np.sum(np.abs(final_eval_scaled["tn_pred"] - final_eval_scaled["tn_real"])) / np.sum(final_eval_scaled["tn_real"])
total_error_2 = np.sum(np.abs(final_eval_scaled["tn_pred_scaled"] - final_eval_scaled["tn_real"])) / np.sum(final_eval_scaled["tn_real"])
print(f"Total error without scaling: {total_error_1}")
print(f"Total error with scaling: {total_error_2}")
# Out:
# Total error without scaling: 0.37683290545212056
# Total error with scaling: 0.21524080665513978

# %%
# entreno pipeline final para kaggle
kaggle_results = {}
for brand, result in pipeline_results.items():
    print(f"Processing brand: {brand}")
    alpha_opt = result["alpha_opt"]
    pipeline = Pipeline(
        steps=[
            LoadDataFrameStep("df_intermedio.parquet"),
            GroupByProductStep(),
            DateRelatedFeaturesStep(),

            FilterDatasetByColumn(column="brand", value=brand),
            #Log1pTranformation(),
            #CreateTargetColumDiffStep(target_col="tn"),
            #CreateTargetColumStep(target_col="tn"),
            CreateResidualTargetStep(target_col="tn", window=12),
            ReduceMemoryUsageStep(),

            #ReduceMemoryUsageStep(),
            FeatureEngineeringLagStep(lags=[1,2,3,5,11,23], columns=["tn", "cust_request_qty", "stock_final"]),
            RollingMeanFeatureStep(window=3, columns=["tn", "cust_request_qty", "stock_final"]),
            RollingMaxFeatureStep(window=3, columns=["tn", "cust_request_qty", "stock_final"]),
            RollingMinFeatureStep(window=3, columns=["tn", "cust_request_qty", "stock_final"]),
            RollingMeanFeatureStep(window=9, columns=["tn", "cust_request_qty", "stock_final"]),
            RollingMaxFeatureStep(window=9, columns=["tn", "cust_request_qty", "stock_final"]),
            RollingMinFeatureStep(window=9, columns=["tn", "cust_request_qty", "stock_final"]),

            ReduceMemoryUsageStep(),

            RollingStdFeatureStep(window=3, columns=["tn", "cust_request_qty"]),
            RollingStdFeatureStep(window=6, columns=["tn", "cust_request_qty"]),
            RollingStdFeatureStep(window=12, columns=["tn", "cust_request_qty"]), 

            RollingSkewFeatureStep(window=3, columns=["tn", "cust_request_qty"]),
            RollingSkewFeatureStep(window=6, columns=["tn", "cust_request_qty"]),
            RollingSkewFeatureStep(window=12, columns=["tn", "cust_request_qty"]),
            ReduceMemoryUsageStep(),

            RollingZscoreFeatureStep(window=3, columns=["tn", "cust_request_qty"]),
            RollingZscoreFeatureStep(window=6, columns=["tn", "cust_request_qty"]),
            RollingZscoreFeatureStep(window=12, columns=["tn", "cust_request_qty"]),
            DiffFeatureStep(periods=1, columns=["tn", "cust_request_qty", "stock_final"]),
            DiffFeatureStep(periods=2, columns=["tn", "cust_request_qty", "stock_final"]),
            DiffFeatureStep(periods=3, columns=["tn", "cust_request_qty", "stock_final"]),
            DiffFeatureStep(periods=4, columns=["tn", "cust_request_qty", "stock_final"]),
            DiffFeatureStep(periods=5, columns=["tn", "cust_request_qty", "stock_final"]),
            DiffFeatureStep(periods=11, columns=["tn", "cust_request_qty", "stock_final"]),
            FeatureEngineeringProductCatInteractionStep(cat="cat1", tn="tn"),
            FeatureEngineeringProductCatInteractionStep(cat="cat2", tn="tn"),
            FeatureEngineeringProductCatInteractionStep(cat="cat3", tn="tn"),
            #FeatureEngineeringProductCatInteractionStep(cat="product_id", tn="tn"),

            CreateTotalCategoryStep(cat="cat1"),
            CreateTotalCategoryStep(cat="cat2"),
            CreateTotalCategoryStep(cat="cat3"),
            CreateTotalCategoryStep(cat="brand"),
            CreateTotalCategoryStep(cat="customer_id"),
            CreateTotalCategoryStep(cat="product_id"),
                    
            CreateTotalCategoryStep(cat="cat1", tn="stock_final"),
            CreateTotalCategoryStep(cat="cat2", tn="stock_final"),
            CreateTotalCategoryStep(cat="cat3", tn="stock_final"),

            #ReduceMemoryUsageStep(),
            FeatureDivInteractionStep(columns=[
                    ("tn", "tn_cat1_vendidas"), 
                    ("tn", "tn_cat2_vendidas"), 
                    ("tn", "tn_cat3_vendidas"), 
                    ("tn", "tn_brand_vendidas")]
            ),
            #ReduceMemoryUsageStep(),

            FeatureProdInteractionStep(columns=[("tn", "cust_request_qty")]),
            CreateWeightByCustomerStep(),
            CreateWeightByProductStep(),
            ReduceMemoryUsageStep(),
            DeleteBadColumns(),
            FilterProductsIDStep(dfs=["df"]),
            SplitDataFrameStep2(df="df", test_date=35, gap=1),
            PrepareXYStep(),
            TrainModelStep(params={"num_leaves":31, "feature_fraction":0.2}),
            PredictStep(),
            InverseResidualTargetStep(),
            #InverseLog1pTranformation(),
            InverseScalePredictionsStep(),
            IntegratePredictionsStep(),
            #PlotFeatureImportanceStep(),
            KaggleSubmissionStep(),
            KaggleSubmissionStep(alpha_opt=alpha_opt, experiment="alpha"),

        ],
        optimize_arftifacts_memory=True
    )

    try: 
        pipeline.run()
        
        # Save the results
        kaggle_results[brand] = {
            "submission": pipeline.get_artifact("submission"),
            "submission_alpha": pipeline.get_artifact("submissionalpha"),
        }
    except Exception as e:
        print(f"Error processing brand {brand}: {e}")
        continue
# Out:
# Processing brand: ARIEL
# Executing step: LoadDataFrameStep
# Step LoadDataFrameStep completed in 2.12 seconds
# Executing step: GroupByProductStep
# Step GroupByProductStep completed in 1.46 seconds
# Executing step: DateRelatedFeaturesStep
# Step DateRelatedFeaturesStep completed in 0.04 seconds
# Executing step: FilterDatasetByColumn
# (761, 16)
# Step FilterDatasetByColumn completed in 0.13 seconds
# Executing step: CreateResidualTargetStep
# Step CreateResidualTargetStep completed in 0.01 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.06 MB
# --- Memory usage after: 0.03 MB
# --- Decreased memory usage by 52.0%
#
# Step ReduceMemoryUsageStep completed in 0.01 seconds
# Executing step: FeatureEngineeringLagStep
# Step FeatureEngineeringLagStep completed in 0.01 seconds
# Executing step: RollingMeanFeatureStep
# Step RollingMeanFeatureStep completed in 0.02 seconds
# Executing step: RollingMaxFeatureStep
# Step RollingMaxFeatureStep completed in 0.02 seconds
# Executing step: RollingMinFeatureStep
# Step RollingMinFeatureStep completed in 0.02 seconds
# Executing step: RollingMeanFeatureStep
# Step RollingMeanFeatureStep completed in 0.02 seconds
# Executing step: RollingMaxFeatureStep
# Step RollingMaxFeatureStep completed in 0.02 seconds
# Executing step: RollingMinFeatureStep
# Step RollingMinFeatureStep completed in 0.02 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.19 MB
# --- Memory usage after: 0.08 MB
# --- Decreased memory usage by 55.9%
#
# Step ReduceMemoryUsageStep completed in 0.02 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 0.02 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 0.01 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 0.02 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 0.02 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 0.02 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 0.02 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.15 MB
# --- Memory usage after: 0.10 MB
# --- Decreased memory usage by 34.4%
#
# Step ReduceMemoryUsageStep completed in 0.02 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 0.03 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 0.02 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 0.03 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.01 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.01 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#      date_id   cat1            tn
# 0          0  FOODS   6490.775391
# 1          0     HC  20304.287109
# 2          0     PC   7183.233887
# 3          0    REF      8.984160
# 4          1  FOODS   7096.089844
# ..       ...    ...           ...
# 139       34    REF      0.470640
# 140       35  FOODS   4907.414551
# 141       35     HC  16045.644531
# 142       35     PC   5263.639160
# 143       35    REF      0.368930
#
# [144 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 0.01 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#      date_id            cat2           tn
# 0          0        ADEREZOS  4844.348145
# 1          0         CABELLO  4586.802246
# 2          0          DENTAL     1.525830
# 3          0            DEOS  1178.932739
# 4          0           HOGAR  2795.374268
# ..       ...             ...          ...
# 535       35     ROPA LAVADO  9541.868164
# 536       35    ROPA MANCHAS   207.274765
# 537       35  SOPAS Y CALDOS   722.231995
# 538       35              TE     0.368930
# 539       35         VAJILLA  2469.144287
#
# [540 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 0.01 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#       date_id              cat3           tn
# 0           0    ACONDICIONADOR  3565.031982
# 1           0        Acond Bebe     0.000000
# 2           0       Acond Mujer   245.138306
# 3           0              Aero   795.659119
# 4           0       Aji Picante     6.321310
# ...       ...               ...          ...
# 3343       35    Toallitas Bebe     5.400110
# 3344       35   Tratamiento Fem     3.135710
# 3345       35  Tratamiento Masc     4.049170
# 3346       35             Verde     0.034220
# 3347       35           Vidrios   230.734436
#
# [3348 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.00 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.00 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: FeatureDivInteractionStep
# Step FeatureDivInteractionStep completed in 0.00 seconds
# Executing step: FeatureProdInteractionStep
# Step FeatureProdInteractionStep completed in 0.00 seconds
# Executing step: CreateWeightByCustomerStep
# Step CreateWeightByCustomerStep completed in 0.01 seconds
# Executing step: CreateWeightByProductStep
# Step CreateWeightByProductStep completed in 0.01 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.55 MB
# --- Memory usage after: 0.33 MB
# --- Decreased memory usage by 40.3%
#
# Step ReduceMemoryUsageStep completed in 0.07 seconds
# Executing step: DeleteBadColumns
# Deleted columns: {'stock_final_lag_23'}
# Step DeleteBadColumns completed in 0.02 seconds
# Executing step: FilterProductsIDStep
# Filtered DataFrame df shape: (259, 219)
# Step FilterProductsIDStep completed in 0.01 seconds
# Executing step: SplitDataFrameStep2
# Step SplitDataFrameStep2 completed in 0.01 seconds
# Executing step: PrepareXYStep
# X_train indexes: Index([    0,  1546,  3515, 25960,     1,  1547,  3516, 25961,     2,  1548,
#        ...
#         3548,  4595,  5079,  8558, 12337, 18765, 19682, 20586, 20755, 25993],
#       dtype='int64', length=235)
# (259, 219)
# Step PrepareXYStep completed in 0.03 seconds
# Executing step: TrainModelStep
# Validation set size: 0
# Step TrainModelStep completed in 0.43 seconds
# Executing step: PredictStep
# Step PredictStep completed in 0.03 seconds
# Executing step: InverseResidualTargetStep
# Step InverseResidualTargetStep completed in 0.02 seconds
# Executing step: InverseScalePredictionsStep
# Step InverseScalePredictionsStep completed in 0.00 seconds
# Executing step: IntegratePredictionsStep
# Step IntegratePredictionsStep completed in 0.00 seconds
# Executing step: KaggleSubmissionStep
# Step KaggleSubmissionStep completed in 0.00 seconds
# Executing step: KaggleSubmissionStep
# Step KaggleSubmissionStep completed in 0.00 seconds
# Processing brand: LIMPIEX
# Executing step: LoadDataFrameStep
# /tmp/ipykernel_98974/3669324445.py:148: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['base_prediction'] = (
# Step LoadDataFrameStep completed in 2.00 seconds
# Executing step: GroupByProductStep
# Step GroupByProductStep completed in 1.45 seconds
# Executing step: DateRelatedFeaturesStep
# Step DateRelatedFeaturesStep completed in 0.04 seconds
# Executing step: FilterDatasetByColumn
# (1843, 16)
# Step FilterDatasetByColumn completed in 0.01 seconds
# Executing step: CreateResidualTargetStep
# Step CreateResidualTargetStep completed in 0.02 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.15 MB
# --- Memory usage after: 0.07 MB
# --- Decreased memory usage by 52.5%
#
# Step ReduceMemoryUsageStep completed in 0.01 seconds
# Executing step: FeatureEngineeringLagStep
# Step FeatureEngineeringLagStep completed in 0.01 seconds
# Executing step: RollingMeanFeatureStep
# Step RollingMeanFeatureStep completed in 0.03 seconds
# Executing step: RollingMaxFeatureStep
# Step RollingMaxFeatureStep completed in 0.03 seconds
# Executing step: RollingMinFeatureStep
# Step RollingMinFeatureStep completed in 0.03 seconds
# Executing step: RollingMeanFeatureStep
# Step RollingMeanFeatureStep completed in 0.03 seconds
# Executing step: RollingMaxFeatureStep
# Step RollingMaxFeatureStep completed in 0.03 seconds
# Executing step: RollingMinFeatureStep
# Step RollingMinFeatureStep completed in 0.03 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.45 MB
# --- Memory usage after: 0.20 MB
# --- Decreased memory usage by 56.1%
#
# Step ReduceMemoryUsageStep completed in 0.02 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 0.03 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 0.02 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 0.02 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 0.03 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 0.03 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 0.03 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.37 MB
# --- Memory usage after: 0.24 MB
# --- Decreased memory usage by 34.5%
#
# Step ReduceMemoryUsageStep completed in 0.02 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 0.05 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 0.05 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 0.04 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.01 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.01 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.01 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.01 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#      date_id   cat1            tn
# 0          0  FOODS   6490.775391
# 1          0     HC  20304.287109
# 2          0     PC   7183.233887
# 3          0    REF      8.984160
# 4          1  FOODS   7096.089844
# ..       ...    ...           ...
# 139       34    REF      0.470640
# 140       35  FOODS   4907.414551
# 141       35     HC  16045.644531
# 142       35     PC   5263.639160
# 143       35    REF      0.368930
#
# [144 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 0.01 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#      date_id            cat2           tn
# 0          0        ADEREZOS  4844.348145
# 1          0         CABELLO  4586.802246
# 2          0          DENTAL     1.525830
# 3          0            DEOS  1178.932739
# 4          0           HOGAR  2795.374268
# ..       ...             ...          ...
# 535       35     ROPA LAVADO  9541.868164
# 536       35    ROPA MANCHAS   207.274765
# 537       35  SOPAS Y CALDOS   722.231995
# 538       35              TE     0.368930
# 539       35         VAJILLA  2469.144287
#
# [540 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 0.01 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#       date_id              cat3           tn
# 0           0    ACONDICIONADOR  3565.031982
# 1           0        Acond Bebe     0.000000
# 2           0       Acond Mujer   245.138306
# 3           0              Aero   795.659119
# 4           0       Aji Picante     6.321310
# ...       ...               ...          ...
# 3343       35    Toallitas Bebe     5.400110
# 3344       35   Tratamiento Fem     3.135710
# 3345       35  Tratamiento Masc     4.049170
# 3346       35             Verde     0.034220
# 3347       35           Vidrios   230.734436
#
# [3348 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 0.02 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.00 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: FeatureDivInteractionStep
# Step FeatureDivInteractionStep completed in 0.00 seconds
# Executing step: FeatureProdInteractionStep
# Step FeatureProdInteractionStep completed in 0.00 seconds
# Executing step: CreateWeightByCustomerStep
# Step CreateWeightByCustomerStep completed in 0.01 seconds
# Executing step: CreateWeightByProductStep
# Step CreateWeightByProductStep completed in 0.01 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 1.32 MB
# --- Memory usage after: 0.79 MB
# --- Decreased memory usage by 40.4%
#
# Step ReduceMemoryUsageStep completed in 0.07 seconds
# Executing step: DeleteBadColumns
# Deleted columns: {'stock_final_lag_23'}
# Step DeleteBadColumns completed in 0.03 seconds
# Executing step: FilterProductsIDStep
# Filtered DataFrame df shape: (1425, 219)
# Step FilterProductsIDStep completed in 0.01 seconds
# Executing step: SplitDataFrameStep2
# Step SplitDataFrameStep2 completed in 0.01 seconds
# Executing step: PrepareXYStep
# X_train indexes: Index([   36,   180,   252,   324,   360,   540,   576,   612,   684,   720,
#        ...
#         7730,  9167,  9357,  9422, 10923, 11824, 14298, 17084, 17814, 18957],
#       dtype='int64', length=1335)
# (1425, 219)
# Step PrepareXYStep completed in 0.03 seconds
# Executing step: TrainModelStep
# Validation set size: 0
# Step TrainModelStep completed in 3.02 seconds
# Executing step: PredictStep
# Step PredictStep completed in 0.20 seconds
# Executing step: InverseResidualTargetStep
# /tmp/ipykernel_98974/3669324445.py:148: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['base_prediction'] = (
# Step InverseResidualTargetStep completed in 0.03 seconds
# Executing step: InverseScalePredictionsStep
# Step InverseScalePredictionsStep completed in 0.00 seconds
# Executing step: IntegratePredictionsStep
# Step IntegratePredictionsStep completed in 0.00 seconds
# Executing step: KaggleSubmissionStep
# Step KaggleSubmissionStep completed in 0.01 seconds
# Executing step: KaggleSubmissionStep
# Step KaggleSubmissionStep completed in 0.00 seconds
# Processing brand: NATURA
# Executing step: LoadDataFrameStep
# Step LoadDataFrameStep completed in 2.03 seconds
# Executing step: GroupByProductStep
# Step GroupByProductStep completed in 1.48 seconds
# Executing step: DateRelatedFeaturesStep
# Step DateRelatedFeaturesStep completed in 0.04 seconds
# Executing step: FilterDatasetByColumn
# (1281, 16)
# Step FilterDatasetByColumn completed in 0.01 seconds
# Executing step: CreateResidualTargetStep
# Step CreateResidualTargetStep completed in 0.01 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.10 MB
# --- Memory usage after: 0.05 MB
# --- Decreased memory usage by 52.4%
#
# Step ReduceMemoryUsageStep completed in 0.00 seconds
# Executing step: FeatureEngineeringLagStep
# Step FeatureEngineeringLagStep completed in 0.01 seconds
# Executing step: RollingMeanFeatureStep
# Step RollingMeanFeatureStep completed in 0.02 seconds
# Executing step: RollingMaxFeatureStep
# Step RollingMaxFeatureStep completed in 0.02 seconds
# Executing step: RollingMinFeatureStep
# Step RollingMinFeatureStep completed in 0.02 seconds
# Executing step: RollingMeanFeatureStep
# Step RollingMeanFeatureStep completed in 0.02 seconds
# Executing step: RollingMaxFeatureStep
# Step RollingMaxFeatureStep completed in 0.03 seconds
# Executing step: RollingMinFeatureStep
# Step RollingMinFeatureStep completed in 0.02 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.31 MB
# --- Memory usage after: 0.14 MB
# --- Decreased memory usage by 56.0%
#
# Step ReduceMemoryUsageStep completed in 0.03 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 0.05 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 0.05 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 0.03 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 0.02 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 0.02 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 0.02 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.26 MB
# --- Memory usage after: 0.17 MB
# --- Decreased memory usage by 34.5%
#
# Step ReduceMemoryUsageStep completed in 0.02 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 0.03 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 0.03 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 0.03 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.01 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.01 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.01 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.01 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#      date_id   cat1            tn
# 0          0  FOODS   6490.775391
# 1          0     HC  20304.287109
# 2          0     PC   7183.233887
# 3          0    REF      8.984160
# 4          1  FOODS   7096.089844
# ..       ...    ...           ...
# 139       34    REF      0.470640
# 140       35  FOODS   4907.414551
# 141       35     HC  16045.644531
# 142       35     PC   5263.639160
# 143       35    REF      0.368930
#
# [144 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 0.01 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#      date_id            cat2           tn
# 0          0        ADEREZOS  4844.348145
# 1          0         CABELLO  4586.802246
# 2          0          DENTAL     1.525830
# 3          0            DEOS  1178.932739
# 4          0           HOGAR  2795.374268
# ..       ...             ...          ...
# 535       35     ROPA LAVADO  9541.868164
# 536       35    ROPA MANCHAS   207.274765
# 537       35  SOPAS Y CALDOS   722.231995
# 538       35              TE     0.368930
# 539       35         VAJILLA  2469.144287
#
# [540 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 0.01 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#       date_id              cat3           tn
# 0           0    ACONDICIONADOR  3565.031982
# 1           0        Acond Bebe     0.000000
# 2           0       Acond Mujer   245.138306
# 3           0              Aero   795.659119
# 4           0       Aji Picante     6.321310
# ...       ...               ...          ...
# 3343       35    Toallitas Bebe     5.400110
# 3344       35   Tratamiento Fem     3.135710
# 3345       35  Tratamiento Masc     4.049170
# 3346       35             Verde     0.034220
# 3347       35           Vidrios   230.734436
#
# [3348 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.00 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: FeatureDivInteractionStep
# Step FeatureDivInteractionStep completed in 0.00 seconds
# Executing step: FeatureProdInteractionStep
# Step FeatureProdInteractionStep completed in 0.00 seconds
# Executing step: CreateWeightByCustomerStep
# Step CreateWeightByCustomerStep completed in 0.01 seconds
# Executing step: CreateWeightByProductStep
# Step CreateWeightByProductStep completed in 0.01 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.92 MB
# --- Memory usage after: 0.55 MB
# --- Decreased memory usage by 40.4%
#
# Step ReduceMemoryUsageStep completed in 0.06 seconds
# Executing step: DeleteBadColumns
# Deleted columns: {'stock_final_lag_23'}
# Step DeleteBadColumns completed in 0.03 seconds
# Executing step: FilterProductsIDStep
# Filtered DataFrame df shape: (863, 219)
# Step FilterProductsIDStep completed in 0.01 seconds
# Executing step: SplitDataFrameStep2
# Step SplitDataFrameStep2 completed in 0.01 seconds
# Executing step: PrepareXYStep
# X_train indexes: Index([   72,   108,   144,   648,  1127,  1582,  3283,  3714,  4044,  4080,
#        ...
#        12373, 12553, 12907, 14255, 14772, 15994, 16449, 17074, 17908, 18728],
#       dtype='int64', length=807)
# (863, 219)
# Step PrepareXYStep completed in 0.03 seconds
# Executing step: TrainModelStep
# Validation set size: 0
# Step TrainModelStep completed in 1.83 seconds
# Executing step: PredictStep
# Step PredictStep completed in 0.04 seconds
# Executing step: InverseResidualTargetStep
# Step InverseResidualTargetStep completed in 0.03 seconds
# Executing step: InverseScalePredictionsStep
# Step InverseScalePredictionsStep completed in 0.00 seconds
# Executing step: IntegratePredictionsStep
# Step IntegratePredictionsStep completed in 0.00 seconds
# Executing step: KaggleSubmissionStep
# Step KaggleSubmissionStep completed in 0.00 seconds
# Executing step: KaggleSubmissionStep
# Step KaggleSubmissionStep completed in 0.01 seconds
# Processing brand: DOWNY
# Executing step: LoadDataFrameStep
# /tmp/ipykernel_98974/3669324445.py:148: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['base_prediction'] = (
# Step LoadDataFrameStep completed in 1.93 seconds
# Executing step: GroupByProductStep
# Step GroupByProductStep completed in 1.52 seconds
# Executing step: DateRelatedFeaturesStep
# Step DateRelatedFeaturesStep completed in 0.04 seconds
# Executing step: FilterDatasetByColumn
# (549, 16)
# Step FilterDatasetByColumn completed in 0.01 seconds
# Executing step: CreateResidualTargetStep
# Step CreateResidualTargetStep completed in 0.01 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.05 MB
# --- Memory usage after: 0.02 MB
# --- Decreased memory usage by 51.6%
#
# Step ReduceMemoryUsageStep completed in 0.01 seconds
# Executing step: FeatureEngineeringLagStep
# Step FeatureEngineeringLagStep completed in 0.01 seconds
# Executing step: RollingMeanFeatureStep
# Step RollingMeanFeatureStep completed in 0.01 seconds
# Executing step: RollingMaxFeatureStep
# Step RollingMaxFeatureStep completed in 0.01 seconds
# Executing step: RollingMinFeatureStep
# Step RollingMinFeatureStep completed in 0.01 seconds
# Executing step: RollingMeanFeatureStep
# Step RollingMeanFeatureStep completed in 0.01 seconds
# Executing step: RollingMaxFeatureStep
# Step RollingMaxFeatureStep completed in 0.01 seconds
# Executing step: RollingMinFeatureStep
# Step RollingMinFeatureStep completed in 0.01 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.14 MB
# --- Memory usage after: 0.06 MB
# --- Decreased memory usage by 55.8%
#
# Step ReduceMemoryUsageStep completed in 0.02 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 0.01 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 0.01 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 0.01 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 0.01 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 0.01 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 0.01 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.11 MB
# --- Memory usage after: 0.07 MB
# --- Decreased memory usage by 34.3%
#
# Step ReduceMemoryUsageStep completed in 0.02 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 0.02 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 0.02 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 0.02 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.01 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#      date_id   cat1            tn
# 0          0  FOODS   6490.775391
# 1          0     HC  20304.287109
# 2          0     PC   7183.233887
# 3          0    REF      8.984160
# 4          1  FOODS   7096.089844
# ..       ...    ...           ...
# 139       34    REF      0.470640
# 140       35  FOODS   4907.414551
# 141       35     HC  16045.644531
# 142       35     PC   5263.639160
# 143       35    REF      0.368930
#
# [144 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 0.01 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#      date_id            cat2           tn
# 0          0        ADEREZOS  4844.348145
# 1          0         CABELLO  4586.802246
# 2          0          DENTAL     1.525830
# 3          0            DEOS  1178.932739
# 4          0           HOGAR  2795.374268
# ..       ...             ...          ...
# 535       35     ROPA LAVADO  9541.868164
# 536       35    ROPA MANCHAS   207.274765
# 537       35  SOPAS Y CALDOS   722.231995
# 538       35              TE     0.368930
# 539       35         VAJILLA  2469.144287
#
# [540 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 0.01 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#       date_id              cat3           tn
# 0           0    ACONDICIONADOR  3565.031982
# 1           0        Acond Bebe     0.000000
# 2           0       Acond Mujer   245.138306
# 3           0              Aero   795.659119
# 4           0       Aji Picante     6.321310
# ...       ...               ...          ...
# 3343       35    Toallitas Bebe     5.400110
# 3344       35   Tratamiento Fem     3.135710
# 3345       35  Tratamiento Masc     4.049170
# 3346       35             Verde     0.034220
# 3347       35           Vidrios   230.734436
#
# [3348 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.00 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.00 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.00 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: FeatureDivInteractionStep
# Step FeatureDivInteractionStep completed in 0.00 seconds
# Executing step: FeatureProdInteractionStep
# Step FeatureProdInteractionStep completed in 0.00 seconds
# Executing step: CreateWeightByCustomerStep
# Step CreateWeightByCustomerStep completed in 0.01 seconds
# Executing step: CreateWeightByProductStep
# Step CreateWeightByProductStep completed in 0.01 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.39 MB
# --- Memory usage after: 0.24 MB
# --- Decreased memory usage by 40.3%
#
# Step ReduceMemoryUsageStep completed in 0.06 seconds
# Executing step: DeleteBadColumns
# Deleted columns: {'stock_final_lag_23'}
# Step DeleteBadColumns completed in 0.02 seconds
# Executing step: FilterProductsIDStep
# Filtered DataFrame df shape: (449, 219)
# Step FilterProductsIDStep completed in 0.01 seconds
# Executing step: SplitDataFrameStep2
# Step SplitDataFrameStep2 completed in 0.01 seconds
# Executing step: PrepareXYStep
# X_train indexes: Index([  216,   396,   468,  1755,  2574,  3013, 11683, 13844, 16389, 16599,
#        ...
#         1716,  1788,  2607,  3046,  7230, 11716, 13877, 16422, 16632, 21744],
#       dtype='int64', length=423)
# (449, 219)
# Step PrepareXYStep completed in 0.03 seconds
# Executing step: TrainModelStep
# Validation set size: 0
# Step TrainModelStep completed in 0.99 seconds
# Executing step: PredictStep
# Step PredictStep completed in 0.03 seconds
# Executing step: InverseResidualTargetStep
# Step InverseResidualTargetStep completed in 0.02 seconds
# Executing step: InverseScalePredictionsStep
# Step InverseScalePredictionsStep completed in 0.00 seconds
# Executing step: IntegratePredictionsStep
# Step IntegratePredictionsStep completed in 0.00 seconds
# Executing step: KaggleSubmissionStep
# Step KaggleSubmissionStep completed in 0.00 seconds
# Executing step: KaggleSubmissionStep
# Step KaggleSubmissionStep completed in 0.00 seconds
# Processing brand: ROPEX1
# Executing step: LoadDataFrameStep
# /tmp/ipykernel_98974/3669324445.py:148: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['base_prediction'] = (
# Step LoadDataFrameStep completed in 1.99 seconds
# Executing step: GroupByProductStep
# Step GroupByProductStep completed in 1.48 seconds
# Executing step: DateRelatedFeaturesStep
# Step DateRelatedFeaturesStep completed in 0.04 seconds
# Executing step: FilterDatasetByColumn
# (658, 16)
# Step FilterDatasetByColumn completed in 0.01 seconds
# Executing step: CreateResidualTargetStep
# Step CreateResidualTargetStep completed in 0.01 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.05 MB
# --- Memory usage after: 0.03 MB
# --- Decreased memory usage by 51.8%
#
# Step ReduceMemoryUsageStep completed in 0.01 seconds
# Executing step: FeatureEngineeringLagStep
# Step FeatureEngineeringLagStep completed in 0.01 seconds
# Executing step: RollingMeanFeatureStep
# Step RollingMeanFeatureStep completed in 0.02 seconds
# Executing step: RollingMaxFeatureStep
# Step RollingMaxFeatureStep completed in 0.02 seconds
# Executing step: RollingMinFeatureStep
# Step RollingMinFeatureStep completed in 0.01 seconds
# Executing step: RollingMeanFeatureStep
# Step RollingMeanFeatureStep completed in 0.01 seconds
# Executing step: RollingMaxFeatureStep
# Step RollingMaxFeatureStep completed in 0.01 seconds
# Executing step: RollingMinFeatureStep
# Step RollingMinFeatureStep completed in 0.01 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.16 MB
# --- Memory usage after: 0.07 MB
# --- Decreased memory usage by 55.9%
#
# Step ReduceMemoryUsageStep completed in 0.02 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 0.01 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 0.01 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 0.01 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 0.01 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 0.01 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 0.01 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.13 MB
# --- Memory usage after: 0.09 MB
# --- Decreased memory usage by 34.3%
#
# Step ReduceMemoryUsageStep completed in 0.02 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 0.02 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 0.02 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 0.02 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.01 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.01 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#      date_id   cat1            tn
# 0          0  FOODS   6490.775391
# 1          0     HC  20304.287109
# 2          0     PC   7183.233887
# 3          0    REF      8.984160
# 4          1  FOODS   7096.089844
# ..       ...    ...           ...
# 139       34    REF      0.470640
# 140       35  FOODS   4907.414551
# 141       35     HC  16045.644531
# 142       35     PC   5263.639160
# 143       35    REF      0.368930
#
# [144 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 0.01 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#      date_id            cat2           tn
# 0          0        ADEREZOS  4844.348145
# 1          0         CABELLO  4586.802246
# 2          0          DENTAL     1.525830
# 3          0            DEOS  1178.932739
# 4          0           HOGAR  2795.374268
# ..       ...             ...          ...
# 535       35     ROPA LAVADO  9541.868164
# 536       35    ROPA MANCHAS   207.274765
# 537       35  SOPAS Y CALDOS   722.231995
# 538       35              TE     0.368930
# 539       35         VAJILLA  2469.144287
#
# [540 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 0.01 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#       date_id              cat3           tn
# 0           0    ACONDICIONADOR  3565.031982
# 1           0        Acond Bebe     0.000000
# 2           0       Acond Mujer   245.138306
# 3           0              Aero   795.659119
# 4           0       Aji Picante     6.321310
# ...       ...               ...          ...
# 3343       35    Toallitas Bebe     5.400110
# 3344       35   Tratamiento Fem     3.135710
# 3345       35  Tratamiento Masc     4.049170
# 3346       35             Verde     0.034220
# 3347       35           Vidrios   230.734436
#
# [3348 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.00 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: FeatureDivInteractionStep
# Step FeatureDivInteractionStep completed in 0.00 seconds
# Executing step: FeatureProdInteractionStep
# Step FeatureProdInteractionStep completed in 0.00 seconds
# Executing step: CreateWeightByCustomerStep
# Step CreateWeightByCustomerStep completed in 0.01 seconds
# Executing step: CreateWeightByProductStep
# Step CreateWeightByProductStep completed in 0.00 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.47 MB
# --- Memory usage after: 0.28 MB
# --- Decreased memory usage by 40.3%
#
# Step ReduceMemoryUsageStep completed in 0.06 seconds
# Executing step: DeleteBadColumns
# Deleted columns: {'stock_final_lag_23'}
# Step DeleteBadColumns completed in 0.02 seconds
# Executing step: FilterProductsIDStep
# Filtered DataFrame df shape: (447, 219)
# Step FilterProductsIDStep completed in 0.01 seconds
# Executing step: SplitDataFrameStep2
# Step SplitDataFrameStep2 completed in 0.01 seconds
# Executing step: PrepareXYStep
# X_train indexes: Index([ 288,  504,  972, 1297, 2286, 2322, 2394, 2466, 2502, 3139,
#        ...
#        2319, 2355, 2427, 2499, 2535, 3172, 5115, 6810, 7808, 8579],
#       dtype='int64', length=419)
# (447, 219)
# Step PrepareXYStep completed in 0.03 seconds
# Executing step: TrainModelStep
# Validation set size: 0
# Step TrainModelStep completed in 0.93 seconds
# Executing step: PredictStep
# Step PredictStep completed in 0.03 seconds
# Executing step: InverseResidualTargetStep
# Step InverseResidualTargetStep completed in 0.02 seconds
# Executing step: InverseScalePredictionsStep
# Step InverseScalePredictionsStep completed in 0.00 seconds
# Executing step: IntegratePredictionsStep
# Step IntegratePredictionsStep completed in 0.00 seconds
# Executing step: KaggleSubmissionStep
# Step KaggleSubmissionStep completed in 0.00 seconds
# Executing step: KaggleSubmissionStep
# Step KaggleSubmissionStep completed in 0.00 seconds
# Processing brand: MUSCULO
# Executing step: LoadDataFrameStep
# /tmp/ipykernel_98974/3669324445.py:148: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['base_prediction'] = (
# Step LoadDataFrameStep completed in 2.00 seconds
# Executing step: GroupByProductStep
# Step GroupByProductStep completed in 1.44 seconds
# Executing step: DateRelatedFeaturesStep
# Step DateRelatedFeaturesStep completed in 0.04 seconds
# Executing step: FilterDatasetByColumn
# (2493, 16)
# Step FilterDatasetByColumn completed in 0.01 seconds
# Executing step: CreateResidualTargetStep
# Step CreateResidualTargetStep completed in 0.02 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.20 MB
# --- Memory usage after: 0.10 MB
# --- Decreased memory usage by 52.6%
#
# Step ReduceMemoryUsageStep completed in 0.01 seconds
# Executing step: FeatureEngineeringLagStep
# Step FeatureEngineeringLagStep completed in 0.01 seconds
# Executing step: RollingMeanFeatureStep
# Step RollingMeanFeatureStep completed in 0.04 seconds
# Executing step: RollingMaxFeatureStep
# Step RollingMaxFeatureStep completed in 0.04 seconds
# Executing step: RollingMinFeatureStep
# Step RollingMinFeatureStep completed in 0.04 seconds
# Executing step: RollingMeanFeatureStep
# Step RollingMeanFeatureStep completed in 0.04 seconds
# Executing step: RollingMaxFeatureStep
# Step RollingMaxFeatureStep completed in 0.04 seconds
# Executing step: RollingMinFeatureStep
# Step RollingMinFeatureStep completed in 0.04 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.61 MB
# --- Memory usage after: 0.27 MB
# --- Decreased memory usage by 56.1%
#
# Step ReduceMemoryUsageStep completed in 0.02 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 0.03 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 0.03 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 0.03 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 0.03 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 0.03 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 0.03 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.50 MB
# --- Memory usage after: 0.32 MB
# --- Decreased memory usage by 34.5%
#
# Step ReduceMemoryUsageStep completed in 0.02 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 0.06 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 0.06 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 0.06 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.01 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.01 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.01 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#      date_id   cat1            tn
# 0          0  FOODS   6490.775391
# 1          0     HC  20304.287109
# 2          0     PC   7183.233887
# 3          0    REF      8.984160
# 4          1  FOODS   7096.089844
# ..       ...    ...           ...
# 139       34    REF      0.470640
# 140       35  FOODS   4907.414551
# 141       35     HC  16045.644531
# 142       35     PC   5263.639160
# 143       35    REF      0.368930
#
# [144 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 0.01 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#      date_id            cat2           tn
# 0          0        ADEREZOS  4844.348145
# 1          0         CABELLO  4586.802246
# 2          0          DENTAL     1.525830
# 3          0            DEOS  1178.932739
# 4          0           HOGAR  2795.374268
# ..       ...             ...          ...
# 535       35     ROPA LAVADO  9541.868164
# 536       35    ROPA MANCHAS   207.274765
# 537       35  SOPAS Y CALDOS   722.231995
# 538       35              TE     0.368930
# 539       35         VAJILLA  2469.144287
#
# [540 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 0.01 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#       date_id              cat3           tn
# 0           0    ACONDICIONADOR  3565.031982
# 1           0        Acond Bebe     0.000000
# 2           0       Acond Mujer   245.138306
# 3           0              Aero   795.659119
# 4           0       Aji Picante     6.321310
# ...       ...               ...          ...
# 3343       35    Toallitas Bebe     5.400110
# 3344       35   Tratamiento Fem     3.135710
# 3345       35  Tratamiento Masc     4.049170
# 3346       35             Verde     0.034220
# 3347       35           Vidrios   230.734436
#
# [3348 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.00 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: FeatureDivInteractionStep
# Step FeatureDivInteractionStep completed in 0.00 seconds
# Executing step: FeatureProdInteractionStep
# Step FeatureProdInteractionStep completed in 0.00 seconds
# Executing step: CreateWeightByCustomerStep
# Step CreateWeightByCustomerStep completed in 0.01 seconds
# Executing step: CreateWeightByProductStep
# Step CreateWeightByProductStep completed in 0.01 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 1.79 MB
# --- Memory usage after: 1.07 MB
# --- Decreased memory usage by 40.4%
#
# Step ReduceMemoryUsageStep completed in 0.07 seconds
# Executing step: DeleteBadColumns
# Deleted columns: {'stock_final_lag_23'}
# Step DeleteBadColumns completed in 0.03 seconds
# Executing step: FilterProductsIDStep
# Filtered DataFrame df shape: (1945, 219)
# Step FilterProductsIDStep completed in 0.01 seconds
# Executing step: SplitDataFrameStep2
# Step SplitDataFrameStep2 completed in 0.01 seconds
# Executing step: PrepareXYStep
# X_train indexes: Index([  432,   936,  1438,  1827,  1971,  2180,  2250,  2358,  2430,  2538,
#        ...
#        24431, 25435, 26375, 26653, 28583, 29953, 30136, 30291, 30389, 30822],
#       dtype='int64', length=1815)
# (1945, 219)
# Step PrepareXYStep completed in 0.03 seconds
# Executing step: TrainModelStep
# Validation set size: 0
# Step TrainModelStep completed in 3.92 seconds
# Executing step: PredictStep
# Step PredictStep completed in 0.04 seconds
# Executing step: InverseResidualTargetStep
# Step InverseResidualTargetStep completed in 0.04 seconds
# Executing step: InverseScalePredictionsStep
# Step InverseScalePredictionsStep completed in 0.00 seconds
# Executing step: IntegratePredictionsStep
# Step IntegratePredictionsStep completed in 0.00 seconds
# Executing step: KaggleSubmissionStep
# ...
# Step RollingMaxFeatureStep completed in 0.01 seconds
# Executing step: RollingMinFeatureStep
# Step RollingMinFeatureStep completed in 0.01 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.03 MB
# --- Memory usage after: 0.01 MB
# --- Decreased memory usage by 51.9%
#
# Step ReduceMemoryUsageStep completed in 0.02 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 0.01 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 0.01 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 0.01 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 0.01 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 0.01 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 0.01 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.02 MB
# --- Memory usage after: 0.02 MB
# --- Decreased memory usage by 32.2%
#
# Step ReduceMemoryUsageStep completed in 0.02 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 0.01 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 0.01 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 0.01 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#      date_id   cat1            tn
# 0          0  FOODS   6490.775391
# 1          0     HC  20304.287109
# 2          0     PC   7183.233887
# 3          0    REF      8.984160
# 4          1  FOODS   7096.089844
# ..       ...    ...           ...
# 139       34    REF      0.470640
# 140       35  FOODS   4907.414551
# 141       35     HC  16045.644531
# 142       35     PC   5263.639160
# 143       35    REF      0.368930
#
# [144 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 0.01 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#      date_id            cat2           tn
# 0          0        ADEREZOS  4844.348145
# 1          0         CABELLO  4586.802246
# 2          0          DENTAL     1.525830
# 3          0            DEOS  1178.932739
# 4          0           HOGAR  2795.374268
# ..       ...             ...          ...
# 535       35     ROPA LAVADO  9541.868164
# 536       35    ROPA MANCHAS   207.274765
# 537       35  SOPAS Y CALDOS   722.231995
# 538       35              TE     0.368930
# 539       35         VAJILLA  2469.144287
#
# [540 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 0.01 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#       date_id              cat3           tn
# 0           0    ACONDICIONADOR  3565.031982
# 1           0        Acond Bebe     0.000000
# 2           0       Acond Mujer   245.138306
# 3           0              Aero   795.659119
# 4           0       Aji Picante     6.321310
# ...       ...               ...          ...
# 3343       35    Toallitas Bebe     5.400110
# 3344       35   Tratamiento Fem     3.135710
# 3345       35  Tratamiento Masc     4.049170
# 3346       35             Verde     0.034220
# 3347       35           Vidrios   230.734436
#
# [3348 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.00 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.00 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.00 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.00 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.00 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.00 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: FeatureDivInteractionStep
# Step FeatureDivInteractionStep completed in 0.00 seconds
# Executing step: FeatureProdInteractionStep
# Step FeatureProdInteractionStep completed in 0.00 seconds
# Executing step: CreateWeightByCustomerStep
# Step CreateWeightByCustomerStep completed in 0.00 seconds
# Executing step: CreateWeightByProductStep
# Step CreateWeightByProductStep completed in 0.01 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.08 MB
# --- Memory usage after: 0.05 MB
# --- Decreased memory usage by 39.7%
#
# Step ReduceMemoryUsageStep completed in 0.06 seconds
# Executing step: DeleteBadColumns
# Deleted columns: {'tn_lag_23', 'cust_request_qty_lag_23', 'stock_final_lag_23'}
# Step DeleteBadColumns completed in 0.02 seconds
# Executing step: FilterProductsIDStep
# Filtered DataFrame df shape: (96, 217)
# Step FilterProductsIDStep completed in 0.01 seconds
# Executing step: SplitDataFrameStep2
# Step SplitDataFrameStep2 completed in 0.01 seconds
# Executing step: PrepareXYStep
# X_train indexes: Index([29807, 30485, 30772, 30997, 31052, 31116, 29808, 30486, 30773, 30998,
#        31053, 31117, 29809, 30487, 30774, 30999, 31054, 31118, 29810, 30488,
#        30775, 31000, 31055, 31119, 29811, 30489, 30776, 31001, 31056, 31120,
#        29812, 30490, 30777, 31002, 31057, 31121, 29813, 30491, 30778, 31003,
#        31058, 31122, 29814, 30492, 30779, 31004, 31059, 31123, 29815, 30493,
#        30780, 31005, 31060, 31124, 29816, 30494, 30781, 31006, 31061, 31125,
#        29817, 30495, 30782, 31007, 31062, 31126, 29818, 30496, 30783, 31008,
#        31063, 31127, 29819, 30497, 30784, 31009, 31064, 31128, 29820, 30498,
#        30785, 31010, 31065, 31129],
#       dtype='int64')
# (96, 217)
# Step PrepareXYStep completed in 0.02 seconds
# Executing step: TrainModelStep
# Validation set size: 0
# Step TrainModelStep completed in 0.17 seconds
# Executing step: PredictStep
# Step PredictStep completed in 0.18 seconds
# Executing step: InverseResidualTargetStep
# /tmp/ipykernel_98974/3669324445.py:148: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['base_prediction'] = (
# Step InverseResidualTargetStep completed in 0.02 seconds
# Executing step: InverseScalePredictionsStep
# Step InverseScalePredictionsStep completed in 0.00 seconds
# Executing step: IntegratePredictionsStep
# Step IntegratePredictionsStep completed in 0.00 seconds
# Executing step: KaggleSubmissionStep
# Step KaggleSubmissionStep completed in 0.00 seconds
# Executing step: KaggleSubmissionStep
# Step KaggleSubmissionStep completed in 0.00 seconds
# Processing brand: VICHY
# Executing step: LoadDataFrameStep
# Step LoadDataFrameStep completed in 1.91 seconds
# Executing step: GroupByProductStep
# Step GroupByProductStep completed in 1.54 seconds
# Executing step: DateRelatedFeaturesStep
# Step DateRelatedFeaturesStep completed in 0.04 seconds
# Executing step: FilterDatasetByColumn
# (119, 16)
# Step FilterDatasetByColumn completed in 0.01 seconds
# Executing step: CreateResidualTargetStep
# Step CreateResidualTargetStep completed in 0.01 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.01 MB
# --- Memory usage after: 0.01 MB
# --- Decreased memory usage by 48.4%
#
# Step ReduceMemoryUsageStep completed in 0.01 seconds
# Executing step: FeatureEngineeringLagStep
# Step FeatureEngineeringLagStep completed in 0.01 seconds
# Executing step: RollingMeanFeatureStep
# Step RollingMeanFeatureStep completed in 0.01 seconds
# Executing step: RollingMaxFeatureStep
# Step RollingMaxFeatureStep completed in 0.01 seconds
# Executing step: RollingMinFeatureStep
# Step RollingMinFeatureStep completed in 0.01 seconds
# Executing step: RollingMeanFeatureStep
# Step RollingMeanFeatureStep completed in 0.01 seconds
# Executing step: RollingMaxFeatureStep
# Step RollingMaxFeatureStep completed in 0.01 seconds
# Executing step: RollingMinFeatureStep
# Step RollingMinFeatureStep completed in 0.01 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.03 MB
# --- Memory usage after: 0.01 MB
# --- Decreased memory usage by 52.1%
#
# Step ReduceMemoryUsageStep completed in 0.02 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 0.01 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 0.01 seconds
# Executing step: RollingStdFeatureStep
# Step RollingStdFeatureStep completed in 0.01 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 0.01 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 0.01 seconds
# Executing step: RollingSkewFeatureStep
# Step RollingSkewFeatureStep completed in 0.01 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.03 MB
# --- Memory usage after: 0.02 MB
# --- Decreased memory usage by 32.3%
#
# Step ReduceMemoryUsageStep completed in 0.02 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 0.01 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 0.01 seconds
# Executing step: RollingZscoreFeatureStep
# Step RollingZscoreFeatureStep completed in 0.01 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: DiffFeatureStep
# Step DiffFeatureStep completed in 0.00 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#      date_id   cat1            tn
# 0          0  FOODS   6490.775391
# 1          0     HC  20304.287109
# 2          0     PC   7183.233887
# 3          0    REF      8.984160
# 4          1  FOODS   7096.089844
# ..       ...    ...           ...
# 139       34    REF      0.470640
# 140       35  FOODS   4907.414551
# 141       35     HC  16045.644531
# 142       35     PC   5263.639160
# 143       35    REF      0.368930
#
# [144 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 0.01 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#      date_id            cat2           tn
# 0          0        ADEREZOS  4844.348145
# 1          0         CABELLO  4586.802246
# 2          0          DENTAL     1.525830
# 3          0            DEOS  1178.932739
# 4          0           HOGAR  2795.374268
# ..       ...             ...          ...
# 535       35     ROPA LAVADO  9541.868164
# 536       35    ROPA MANCHAS   207.274765
# 537       35  SOPAS Y CALDOS   722.231995
# 538       35              TE     0.368930
# 539       35         VAJILLA  2469.144287
#
# [540 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 0.01 seconds
# Executing step: FeatureEngineeringProductCatInteractionStep
#       date_id              cat3           tn
# 0           0    ACONDICIONADOR  3565.031982
# 1           0        Acond Bebe     0.000000
# 2           0       Acond Mujer   245.138306
# 3           0              Aero   795.659119
# 4           0       Aji Picante     6.321310
# ...       ...               ...          ...
# 3343       35    Toallitas Bebe     5.400110
# 3344       35   Tratamiento Fem     3.135710
# 3345       35  Tratamiento Masc     4.049170
# 3346       35             Verde     0.034220
# 3347       35           Vidrios   230.734436
#
# [3348 rows x 3 columns]
# Step FeatureEngineeringProductCatInteractionStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.00 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.00 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.00 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.00 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.00 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: CreateTotalCategoryStep
# Step CreateTotalCategoryStep completed in 0.01 seconds
# Executing step: FeatureDivInteractionStep
# Step FeatureDivInteractionStep completed in 0.00 seconds
# Executing step: FeatureProdInteractionStep
# Step FeatureProdInteractionStep completed in 0.00 seconds
# Executing step: CreateWeightByCustomerStep
# Step CreateWeightByCustomerStep completed in 0.00 seconds
# Executing step: CreateWeightByProductStep
# Step CreateWeightByProductStep completed in 0.01 seconds
# Executing step: ReduceMemoryUsageStep
# --- Memory usage before: 0.09 MB
# --- Memory usage after: 0.05 MB
# --- Decreased memory usage by 39.7%
#
# Step ReduceMemoryUsageStep completed in 0.06 seconds
# Executing step: DeleteBadColumns
# Deleted columns: {'tn_lag_23', 'cust_request_qty_lag_23', 'stock_final_lag_23'}
# Step DeleteBadColumns completed in 0.02 seconds
# Executing step: FilterProductsIDStep
# Filtered DataFrame df shape: (105, 217)
# Step FilterProductsIDStep completed in 0.01 seconds
# Executing step: SplitDataFrameStep2
# Step SplitDataFrameStep2 completed in 0.01 seconds
# Executing step: PrepareXYStep
# X_train indexes: Index([31101, 31132, 31150, 31225, 31276, 31315, 31330, 31102, 31133, 31151,
#        31226, 31277, 31316, 31331, 31103, 31134, 31152, 31227, 31278, 31317,
#        31332, 31104, 31135, 31153, 31228, 31279, 31318, 31333, 31105, 31136,
#        31154, 31229, 31280, 31319, 31334, 31106, 31137, 31155, 31230, 31281,
#        31320, 31335, 31107, 31138, 31156, 31231, 31282, 31321, 31336, 31108,
#        31139, 31157, 31232, 31283, 31322, 31337, 31109, 31140, 31158, 31233,
#        31284, 31323, 31338, 31110, 31141, 31159, 31234, 31285, 31324, 31339,
#        31111, 31142, 31160, 31235, 31286, 31325, 31340, 31112, 31143, 31161,
#        31236, 31287, 31326, 31341, 31113, 31144, 31162, 31237, 31288, 31327,
#        31342],
#       dtype='int64')
# (105, 217)
# Step PrepareXYStep completed in 0.02 seconds
# Executing step: TrainModelStep
# Validation set size: 0
# Step TrainModelStep completed in 0.19 seconds
# Executing step: PredictStep
# Step PredictStep completed in 0.03 seconds
# Executing step: InverseResidualTargetStep
# Step InverseResidualTargetStep completed in 0.02 seconds
# Executing step: InverseScalePredictionsStep
# Step InverseScalePredictionsStep completed in 0.00 seconds
# Executing step: IntegratePredictionsStep
# Step IntegratePredictionsStep completed in 0.00 seconds
# Executing step: KaggleSubmissionStep
# Step KaggleSubmissionStep completed in 0.00 seconds
# Executing step: KaggleSubmissionStep
# Step KaggleSubmissionStep completed in 0.01 seconds
# /tmp/ipykernel_98974/3669324445.py:148: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['base_prediction'] = (

# %%
final_submission_scaled = pd.DataFrame(columns=["product_id", "tn"])
final_submission_no_scaled = pd.DataFrame(columns=["product_id", "tn"])
for brand, result in kaggle_results.items():
    submission_normal = result["submission"]
    submission_alpha = result["submission_alpha"]
    final_submission_no_scaled = pd.concat([final_submission_no_scaled, submission_normal], ignore_index=True)
    final_submission_scaled = pd.concat([final_submission_scaled, submission_alpha], ignore_index=True)

# %%
final_submission_no_scaled
# Out:
#     product_id           tn
# 0        20001  1345.738387
# 1        20045   170.647413
# 2        20102    11.787400
# 3        20135   137.287058
# 4        20150    38.643878
# ..         ...          ...
# 775      21248    -0.087762
# 776      21256    -0.097195
# 777      21259    -0.083637
# 778      21262    -0.096032
# 779      21263    -0.089014
#
# [780 rows x 2 columns]

# %%
final_submission_scaled
# Out:
#     product_id           tn
# 0        20001  1133.218058
# 1        20045   143.698605
# 2        20102     9.925922
# 3        20135   115.606551
# 4        20150    32.541199
# ..         ...          ...
# 775      21248     0.000000
# 776      21256     0.000000
# 777      21259     0.000000
# 778      21262     0.000000
# 779      21263     0.000000
#
# [780 rows x 2 columns]

# %%
# pasar final_submission_no_scaled a menor a 0 a 0
final_submission_no_scaled["tn"] = final_submission_no_scaled["tn"].apply(lambda x: max(x, 0))

# %%
final_submission_scaled["tn"] = final_submission_scaled["tn"].apply(lambda x: max(x, 0))

# %%
final_submission_no_scaled.to_csv("submission_no_scaled.csv", index=False)
final_submission_scaled.to_csv("submission_scaled.csv", index=False)
